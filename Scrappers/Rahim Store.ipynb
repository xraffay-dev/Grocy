# %%
import asyncio
from playwright.async_api import async_playwright
import csv
import os
from typing import List, Dict, Optional
import logging
from datetime import datetime
import time
import sys

# Set up detailed logging with real-time output
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s | %(levelname)-8s | %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('rahim_scraper_detailed.log', encoding='utf-8'),
        logging.StreamHandler(sys.stdout)
    ]
)
logger = logging.getLogger(__name__)

class RahimStoreScraper:
    def __init__(self):
        self.base_url = "https://www.rahimstore.com/department/"
        self.departments = ['001', '002', '003', '004', '005', '006', '007']
        self.output_file = f'rahim_store_products_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv'
        self.product_data = []
        self.stats = {
            'total_products': 0,
            'failed_products': 0,
            'department_stats': {},
            'start_time': None,
            'end_time': None,
            'current_department': None,
            'current_page': 0
        }

    def print_banner(self):
        """Print startup banner"""
        print("\n" + "═" * 80)
        print("RAHIM STORE WEB SCRAPER - REAL-TIME MONITORING")
        print("═" * 80)
        print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"Output file: {self.output_file}")
        print(f"Departments: {', '.join(self.departments)}")
        print("═" * 80)
        print("LIVE LOGS STARTING...")
        print("─" * 80)

    def print_live_status(self, action: str, details: str = ""):
        """Print real-time status updates"""
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f"[{timestamp}] {action}: {details}")

    def print_product_extracted(self, product_name: str, product_id: str, price: str):
        """Print when a product is successfully extracted"""
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f"[{timestamp}] EXTRACTED: '{product_name}' (ID: {product_id}) - Price: {price}")

    def print_page_progress(self, dept: str, page: int, current: int, total: int):
        """Print page-by-page progress"""
        progress = f"Dept {dept} | Page {page} | Progress: {current}/{total} products"

    def print_department_summary(self, dept: str, total_products: int, duration: float):
        """Print department completion summary"""
        print("─" * 80)
        print(f"DEPARTMENT {dept} COMPLETED!")
        print(f"Total products: {total_products}")
        print(f"Time taken: {duration:.2f} seconds")
        print("─" * 80)

    def print_final_summary(self):
        """Print final summary"""
        total_duration = self.stats['end_time'] - self.stats['start_time']

        print("\n" + "═" * 80)
        print("SCRAPING COMPLETED - FINAL SUMMARY")
        print("═" * 80)
        print(f"Total duration: {total_duration:.2f} seconds")
        print(f"Total products: {self.stats['total_products']}")
        print(f"Failed extractions: {self.stats['failed_products']}")
        print(f"Output file: {self.output_file}")

        print("\nDEPARTMENT BREAKDOWN:")
        for dept in self.departments:
            count = self.stats['department_stats'].get(dept, 0)
            print(f"   └── Department {dept}: {count} products")

        total_attempts = self.stats['total_products'] + self.stats['failed_products']
        success_rate = (self.stats['total_products'] / total_attempts * 100) if total_attempts > 0 else 0
        print(f"\nSuccess rate: {success_rate:.1f}%")
        print("═" * 80)

    async def setup_browser(self) -> bool:
        """Initialize browser and context"""
        try:
            self.print_live_status("INITIALIZING BROWSER", "Starting Playwright...")
            self.stats['start_time'] = time.time()

            self.playwright = await async_playwright().start()
            self.browser = await self.playwright.chromium.launch(
                headless=True,
                args=[
                    '--no-sandbox',
                    '--disable-dev-shm-usage',
                    '--disable-blink-features=AutomationControlled',
                    '--disable-features=VizDisplayCompositor'
                ]
            )

            self.context = await self.browser.new_context(
                viewport={'width': 1920, 'height': 1080},
                user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
                extra_http_headers={
                    'Accept-Language': 'en-US,en;q=0.9',
                    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'
                }
            )

            self.print_live_status("BROWSER READY", "Chromium initialized successfully")
            return True

        except Exception as e:
            self.print_live_status("BROWSER FAILED", f"Error: {str(e)}")
            return False

    async def close_browser(self):
        """Close browser resources"""
        try:
            if hasattr(self, 'context'):
                await self.context.close()
            if hasattr(self, 'browser'):
                await self.browser.close()
            if hasattr(self, 'playwright'):
                await self.playwright.stop()
            self.print_live_status("BROWSER CLOSED", "All resources cleaned up")
        except Exception as e:
            self.print_live_status("CLEANUP ERROR", f"Error: {str(e)}")

    def save_to_csv(self) -> bool:
        """Save data to CSV file"""
        try:
            if not self.product_data:
                self.print_live_status("CSV SAVE", "No data to save")
                return False

            fieldnames = [
                'department_id', 'product_id', 'product_name', 'current_price',
                'original_price', 'product_url', 'image_url', 'was_price',
                'scraped_timestamp'
            ]

            with open(self.output_file, 'w', newline='', encoding='utf-8') as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(self.product_data)

            self.print_live_status("CSV SAVED", f"{len(self.product_data)} products saved to {self.output_file}")
            return True

        except Exception as e:
            self.print_live_status("CSV ERROR", f"Failed to save: {str(e)}")
            return False

    async def wait_for_products_fully_loaded(self, page, department_id: str, page_number: int):
        """Wait for products to be fully loaded with multiple verification steps"""
        try:
            self.print_live_status("WAITING", f"Waiting for products to fully load on page {page_number}")

            # Wait for the main product container to be present
            await page.wait_for_selector('.item.img-hover-zoom--quick-zoom', timeout=20000)
            self.print_live_status("LOAD CHECK", "Initial product container found")

            # Wait for additional time to ensure all content is loaded
            await asyncio.sleep(2)

            # Check if product images are loaded
            images_loaded = await page.query_selector_all('img.img-fluid[src]')
            self.print_live_status("LOAD CHECK", f"{len(images_loaded)} product images found")

            # Wait for prices to be loaded
            prices_loaded = await page.query_selector_all('strong')
            self.print_live_status("LOAD CHECK", f"{len(prices_loaded)} price elements found")

            # Final wait to ensure everything is rendered
            await asyncio.sleep(1)

            self.print_live_status("LOAD COMPLETE", "All products fully loaded and ready for scraping")
            return True

        except Exception as e:
            self.print_live_status("LOAD ERROR", f"Failed to wait for products: {str(e)}")
            return False

    async def extract_product_info(self, product_card, department_id: str, card_index: int) -> Optional[Dict]:
        """Extract detailed product information with real-time logging"""
        try:
            # Extract product name
            name_element = await product_card.query_selector('a[style="display:block; height:50px;"]')
            if not name_element:
                self.print_live_status("EXTRACTION FAILED", f"Card {card_index}: No name element found")
                return None

            product_name = await name_element.inner_text()
            product_name = product_name.strip() if product_name else "N/A"

            # Extract product URL and ID
            product_url = await name_element.get_attribute('href') or "N/A"
            product_id = await name_element.get_attribute('productid') or "N/A"

            # Extract image
            img_element = await product_card.query_selector('img.img-fluid')
            image_url = await img_element.get_attribute('src') if img_element else "N/A"

            # Extract prices
            strong_element = await product_card.query_selector('strong')
            current_price = await strong_element.inner_text() if strong_element else "N/A"
            current_price = current_price.replace('Rs', '').replace('sup', '').strip()

            strike_element = await product_card.query_selector('strike')
            was_price = await strike_element.inner_text() if strike_element else "N/A"

            # Get additional price data from button
            button_element = await product_card.query_selector('button.btn-success')
            original_price = was_price

            if button_element:
                button_data = await button_element.get_attribute('data')
                if button_data and '~' in button_data:
                    data_parts = button_data.split('~')
                    if len(data_parts) >= 4:
                        original_price = data_parts[3]

            product_info = {
                'department_id': department_id,
                'product_id': product_id,
                'product_name': product_name,
                'current_price': current_price,
                'original_price': original_price,
                'product_url': product_url,
                'image_url': image_url,
                'was_price': was_price,
                'scraped_timestamp': datetime.now().isoformat()
            }

            # Print successful extraction
            self.print_product_extracted(product_name, product_id, current_price)
            return product_info

        except Exception as e:
            self.print_live_status("EXTRACTION ERROR", f"Card {card_index}: {str(e)}")
            self.stats['failed_products'] += 1
            return None

    async def handle_pagination(self, page, department_id: str, current_page: int) -> bool:
        """Handle pagination to next page with proper waiting"""
        try:
            self.print_live_status("PAGINATION", f"Checking for page {current_page + 1}")

            # Wait for pagination to load
            await page.wait_for_selector('.pagination', timeout=10000)

            # Find next button
            next_button = await page.query_selector('a.page-link[aria-label="Next"]')
            if not next_button:
                self.print_live_status("PAGINATION", "No next button found")
                return False

            # Check if next button is disabled
            is_disabled = await next_button.evaluate('(element) => element.parentElement.classList.contains("disabled")')
            if is_disabled:
                self.print_live_status("PAGINATION", f"Reached last page ({current_page})")
                return False

            # Click next button
            self.print_live_status("PAGINATION", f"Moving to page {current_page + 1}")
            await next_button.click()

            # Wait for navigation to complete and new page to load
            self.print_live_status("WAITING", "Waiting for new page to load after pagination...")
            await page.wait_for_timeout(4000)  # Increased wait time for page transition

            # Wait for products to be fully loaded on the new page
            await self.wait_for_products_fully_loaded(page, department_id, current_page + 1)

            self.print_live_status("PAGINATION", f"Successfully loaded page {current_page + 1}")
            return True

        except Exception as e:
            self.print_live_status("PAGINATION ERROR", f"Page {current_page}: {str(e)}")
            return False

    async def scrape_department_page(self, page, department_id: str, page_number: int) -> bool:
        """Scrape a single page of products with proper loading waits"""
        try:
            self.stats['current_page'] = page_number
            self.print_live_status("PAGE START", f"Department {department_id} - Page {page_number}")

            # Wait for products to be fully loaded before scraping
            if not await self.wait_for_products_fully_loaded(page, department_id, page_number):
                self.print_live_status("PAGE ERROR", f"Products not loaded properly on page {page_number}")
                return False

            # Get all product cards after ensuring they're loaded
            product_cards = await page.query_selector_all('.item.img-hover-zoom--quick-zoom')

            if not product_cards:
                self.print_live_status("PAGE EMPTY", "No product cards found after waiting")
                return False

            self.print_live_status("PRODUCTS FOUND", f"Found {len(product_cards)} products on page {page_number}")

            # Extract each product with small delays between extractions
            successful_extractions = 0
            for i, card in enumerate(product_cards, 1):
                # Show progress every 5 products
                if i % 5 == 0 or i == len(product_cards):
                    self.print_page_progress(department_id, page_number, i, len(product_cards))

                # Small delay between product extractions to be respectful
                if i > 1:
                    await asyncio.sleep(0.1)

                product_info = await self.extract_product_info(card, department_id, i)
                if product_info:
                    self.product_data.append(product_info)
                    successful_extractions += 1
                    self.stats['total_products'] += 1

            self.print_live_status("PAGE COMPLETE",
                f"Page {page_number}: {successful_extractions}/{len(product_cards)} products extracted")

            # Handle pagination
            has_next_page = await self.handle_pagination(page, department_id, page_number)
            return has_next_page

        except Exception as e:
            self.print_live_status("PAGE ERROR", f"Department {department_id} Page {page_number}: {str(e)}")
            return False

    async def scrape_department(self, department_id: str):
        """Scrape all pages of a department with proper loading waits"""
        dept_start_time = time.time()
        url = f"{self.base_url}{department_id}"

        self.stats['current_department'] = department_id
        print(f"\n{'=' * 80}")
        print(f"STARTING DEPARTMENT {department_id}")
        print(f"URL: {url}")
        print(f"{'=' * 80}")

        page = await self.context.new_page()
        dept_products_start = len(self.product_data)

        try:
            # Navigate to department with longer timeout
            self.print_live_status("NAVIGATING", f"Loading {url} (waiting for full load)...")
            response = await page.goto(url, wait_until='domcontentloaded', timeout=45000)

            if not response or response.status != 200:
                status_code = getattr(response, 'status', 'Unknown')
                self.print_live_status("NAVIGATION FAILED", f"HTTP {status_code}")
                return

            self.print_live_status("PAGE LOADED", "Initial page loaded, waiting for full content...")

            # Wait for the department page to be fully ready
            await self.wait_for_products_fully_loaded(page, department_id, 1)

            # Scrape all pages
            page_number = 1
            max_pages = 100  # Safety limit

            while page_number <= max_pages:
                has_next_page = await self.scrape_department_page(page, department_id, page_number)

                if not has_next_page:
                    self.print_live_status("DEPARTMENT COMPLETE", f"No more pages after page {page_number}")
                    break

                page_number += 1
                # Increased pause between pages
                await asyncio.sleep(2)

            # Department summary
            dept_products_count = len(self.product_data) - dept_products_start
            self.stats['department_stats'][department_id] = dept_products_count
            dept_duration = time.time() - dept_start_time

            self.print_department_summary(department_id, dept_products_count, dept_duration)

        except Exception as e:
            self.print_live_status("DEPARTMENT ERROR", f"Department {department_id}: {str(e)}")
        finally:
            await page.close()
            self.print_live_status("PAGE CLOSED", f"Department {department_id} browser page closed")

    async def run_scraper(self):
        """Main scraper execution function"""
        self.print_banner()

        if not await self.setup_browser():
            return

        try:
            # Scrape each department
            for i, department_id in enumerate(self.departments, 1):
                print(f"\nOVERALL PROGRESS: Department {i}/{len(self.departments)}")
                await self.scrape_department(department_id)

                # Longer pause between departments to be respectful
                if i < len(self.departments):
                    self.print_live_status("PAUSING", "Waiting 5 seconds before next department...")
                    await asyncio.sleep(5)

            # Final save and summary
            self.stats['end_time'] = time.time()
            self.save_to_csv()
            self.print_final_summary()

        except KeyboardInterrupt:
            self.print_live_status("INTERRUPTED", "User stopped the scraper")
            print("\nSaving collected data before exit...")
            self.save_to_csv()
        except Exception as e:
            self.print_live_status("FATAL ERROR", f"Scraper crashed: {str(e)}")
        finally:
            await self.close_browser()

async def main():
    """Main execution function"""
    print("Initializing Rahim Store Scraper with Real-time Monitoring...")

    try:
        scraper = RahimStoreScraper()
        await scraper.run_scraper()
    except Exception as e:
        print(f"Fatal initialization error: {e}")

if __name__ == "__main__":
    # Run the scraper
    await main()
# Out:
# Streaming output truncated to the last 5000 lines.
# [15:34:33] LOAD CHECK: Initial product container found
# [15:34:35] LOAD CHECK: 20 product images found
# [15:34:35] LOAD CHECK: 22 price elements found
# [15:34:36] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:34:36] PRODUCTS FOUND: Found 33 products on page 13
# [15:34:36] EXTRACTION FAILED: Card 1: No name element found
# [15:34:36] EXTRACTION FAILED: Card 2: No name element found
# [15:34:36] EXTRACTION FAILED: Card 3: No name element found
# [15:34:36] EXTRACTION FAILED: Card 4: No name element found
# [15:34:37] EXTRACTION FAILED: Card 5: No name element found
# [15:34:37] EXTRACTION FAILED: Card 6: No name element found
# [15:34:37] EXTRACTION FAILED: Card 7: No name element found
# [15:34:37] EXTRACTION FAILED: Card 8: No name element found
# [15:34:37] EXTRACTION FAILED: Card 9: No name element found
# [15:34:37] EXTRACTION FAILED: Card 10: No name element found
# [15:34:37] EXTRACTION FAILED: Card 11: No name element found
# [15:34:37] EXTRACTION FAILED: Card 12: No name element found
# [15:34:38] EXTRACTION FAILED: Card 13: No name element found
# [15:34:38] EXTRACTED: 'Peek Freans Smile Strawberry D' (ID: 27607) - Price: 50.00
# [15:34:38] EXTRACTED: 'Cadbury Dairy Milk Roast Almon' (ID: 28176) - Price: 500.00
# [15:34:38] EXTRACTED: 'Kolson Slanty Vegetable 43gm' (ID: 28307) - Price: 30.00
# [15:34:38] EXTRACTED: 'Yupi Aquarium Jelly 14gm' (ID: 29488) - Price: 70.00
# [15:34:39] EXTRACTED: 'Peek Freans Rio Strawberry Van' (ID: 29494) - Price: 10.00
# [15:34:39] EXTRACTED: 'Bisconni Mi Amor Chocolate Coo' (ID: 29713) - Price: 40.00
# [15:34:39] EXTRACTED: 'Hilal Fresh Up Xtra Spearmint' (ID: 29718) - Price: 245.00
# [15:34:39] EXTRACTED: 'Peek Freans Lemon Sandwich Tic' (ID: 29736) - Price: 10.00
# [15:34:40] EXTRACTED: 'Peek Freans Original Lemon San' (ID: 29777) - Price: 40.00
# [15:34:40] EXTRACTED: 'Lu Gala Egg Biscuits' (ID: 29980) - Price: 20.00
# [15:34:40] EXTRACTED: 'Inovative Crust Chocolate Snac' (ID: 30112) - Price: 10.00
# [15:34:40] EXTRACTED: 'Lu Prince Mini Stars' (ID: 30232) - Price: 20.00
# [15:34:40] EXTRACTED: 'Shahi Meva Mix Dry Fruit Box' (ID: 30258) - Price: 240.00
# [15:34:41] EXTRACTED: 'Shahi Elaichi Herbal Mouth Fre' (ID: 30260) - Price: 240.00
# [15:34:41] EXTRACTED: 'Tulsi Classic Pan Masala 24pcs' (ID: 30334) - Price: 240.00
# [15:34:41] EXTRACTED: 'Tulsi Zero Supari Meeth Pan Ma' (ID: 30338) - Price: 240.00
# [15:34:41] EXTRACTED: 'Tulsi Gold Meetha Pan Masala B' (ID: 30342) - Price: 240.00
# [15:34:42] EXTRACTED: 'Tulsi Special Mouth Freshner B' (ID: 30343) - Price: 120.00
# [15:34:42] EXTRACTED: 'Bisconni Digestive Biscuits 30' (ID: 30354) - Price: 30.00
# [15:34:42] EXTRACTED: 'Inovative Crust Strawberry Sna' (ID: 30393) - Price: 10.00
# [15:34:42] PAGE COMPLETE: Page 13: 20/33 products extracted
# [15:34:42] PAGINATION: Checking for page 14
# [15:34:42] PAGINATION: Moving to page 14
# [15:34:42] WAITING: Waiting for new page to load after pagination...
# [15:34:46] WAITING: Waiting for products to fully load on page 14
# [15:34:46] LOAD CHECK: Initial product container found
# [15:34:48] LOAD CHECK: 20 product images found
# [15:34:48] LOAD CHECK: 22 price elements found
# [15:34:49] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:34:49] PAGINATION: Successfully loaded page 14
# [15:34:51] PAGE START: Department 005 - Page 14
# [15:34:51] WAITING: Waiting for products to fully load on page 14
# [15:34:51] LOAD CHECK: Initial product container found
# [15:34:53] LOAD CHECK: 20 product images found
# [15:34:53] LOAD CHECK: 22 price elements found
# [15:34:54] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:34:54] PRODUCTS FOUND: Found 33 products on page 14
# [15:34:54] EXTRACTION FAILED: Card 1: No name element found
# [15:34:55] EXTRACTION FAILED: Card 2: No name element found
# [15:34:55] EXTRACTION FAILED: Card 3: No name element found
# [15:34:55] EXTRACTION FAILED: Card 4: No name element found
# [15:34:55] EXTRACTION FAILED: Card 5: No name element found
# [15:34:55] EXTRACTION FAILED: Card 6: No name element found
# [15:34:55] EXTRACTION FAILED: Card 7: No name element found
# [15:34:55] EXTRACTION FAILED: Card 8: No name element found
# [15:34:55] EXTRACTION FAILED: Card 9: No name element found
# [15:34:55] EXTRACTION FAILED: Card 10: No name element found
# [15:34:56] EXTRACTION FAILED: Card 11: No name element found
# [15:34:56] EXTRACTION FAILED: Card 12: No name element found
# [15:34:56] EXTRACTION FAILED: Card 13: No name element found
# [15:34:56] EXTRACTED: 'Hilal Wispy Chocolate Wafer Ro' (ID: 30396) - Price: 240.00
# [15:34:56] EXTRACTED: 'Kolson Folds Hot Sriracha Flav' (ID: 32498) - Price: 50.00
# [15:34:56] EXTRACTED: 'Nutro Kreme Wafers Vanilla 75g' (ID: 32507) - Price: 485.00
# [15:34:57] EXTRACTED: 'Nutro Kreme Wafers Strawberry' (ID: 32508) - Price: 683.00
# [15:34:57] EXTRACTED: 'Bisconni Cocomo Triple Choc Mi' (ID: 32522) - Price: 10.00
# [15:34:57] EXTRACTED: 'Loacker Classic Chocolate Wafe' (ID: 32527) - Price: 745.00
# [15:34:57] EXTRACTED: 'Loacker Hazelnut Wafer 175gm' (ID: 32528) - Price: 750.00
# [15:34:57] EXTRACTED: 'Mayfair Fruit Gala Jumbo Green' (ID: 32574) - Price: 200.00
# [15:34:58] EXTRACTED: 'Lu Wheatable Elaichi Bar Pack' (ID: 32598) - Price: 20.00
# [15:34:58] EXTRACTED: 'Bisconni Rite Vanilla Cream Sn' (ID: 32614) - Price: 20.00
# [15:34:58] EXTRACTED: 'Lu Milcolu Waffle Milk Biscuit' (ID: 32658) - Price: 30.00
# [15:34:58] EXTRACTED: 'Bisconni Cocomo Triple Choc Po' (ID: 33746) - Price: 100.00
# [15:34:58] EXTRACTED: 'Kolson Folds Sriracha Snacks 2' (ID: 33752) - Price: 30.00
# [15:34:59] EXTRACTED: 'Bisconni Chocolate Chip Cookie' (ID: 33755) - Price: 30.00
# [15:34:59] EXTRACTED: 'Lu Milcolu Waffel Milk Biscuit' (ID: 33770) - Price: 20.00
# [15:34:59] EXTRACTED: 'Peek Freans Choco Licious Vani' (ID: 33771) - Price: 30.00
# [15:34:59] EXTRACTED: 'Peek Freans Chocolate Sandwich' (ID: 33774) - Price: 40.00
# [15:34:59] EXTRACTED: 'Peek Freans Butter Puff Half R' (ID: 33784) - Price: 40.00
# [15:35:00] EXTRACTED: 'Inovative Butter Crunch 47.7gm' (ID: 33822) - Price: 30.00
# [15:35:00] EXTRACTED: 'Lu Wheatable Digestive Bar Pac' (ID: 33830) - Price: 20.00
# [15:35:00] PAGE COMPLETE: Page 14: 20/33 products extracted
# [15:35:00] PAGINATION: Checking for page 15
# [15:35:00] PAGINATION: Moving to page 15
# [15:35:00] WAITING: Waiting for new page to load after pagination...
# [15:35:04] WAITING: Waiting for products to fully load on page 15
# [15:35:04] LOAD CHECK: Initial product container found
# [15:35:06] LOAD CHECK: 20 product images found
# [15:35:06] LOAD CHECK: 22 price elements found
# [15:35:07] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:07] PAGINATION: Successfully loaded page 15
# [15:35:09] PAGE START: Department 005 - Page 15
# [15:35:09] WAITING: Waiting for products to fully load on page 15
# [15:35:09] LOAD CHECK: Initial product container found
# [15:35:11] LOAD CHECK: 20 product images found
# [15:35:11] LOAD CHECK: 22 price elements found
# [15:35:12] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:12] PRODUCTS FOUND: Found 33 products on page 15
# [15:35:12] EXTRACTION FAILED: Card 1: No name element found
# [15:35:12] EXTRACTION FAILED: Card 2: No name element found
# [15:35:12] EXTRACTION FAILED: Card 3: No name element found
# [15:35:12] EXTRACTION FAILED: Card 4: No name element found
# [15:35:12] EXTRACTION FAILED: Card 5: No name element found
# [15:35:13] EXTRACTION FAILED: Card 6: No name element found
# [15:35:13] EXTRACTION FAILED: Card 7: No name element found
# [15:35:13] EXTRACTION FAILED: Card 8: No name element found
# [15:35:13] EXTRACTION FAILED: Card 9: No name element found
# [15:35:13] EXTRACTION FAILED: Card 10: No name element found
# [15:35:13] EXTRACTION FAILED: Card 11: No name element found
# [15:35:13] EXTRACTION FAILED: Card 12: No name element found
# [15:35:13] EXTRACTION FAILED: Card 13: No name element found
# [15:35:13] EXTRACTED: 'Lu Zeera Plus' (ID: 33850) - Price: 30.00
# [15:35:14] EXTRACTED: 'Bisconni Fudge Brownie Cake' (ID: 33871) - Price: 40.00
# [15:35:14] EXTRACTED: 'Lu Wheatable Sugar Free Bar Pa' (ID: 34010) - Price: 20.00
# [15:35:14] EXTRACTED: 'Lu Gala Biscuit Half Roll' (ID: 34023) - Price: 40.00
# [15:35:14] EXTRACTED: 'Inovative Butter Crunch Half R' (ID: 34043) - Price: 40.00
# [15:35:14] EXTRACTED: 'Inovative Too Gud Mini Half Pa' (ID: 34045) - Price: 20.00
# [15:35:15] EXTRACTED: 'Inovative Goodies Half Pack' (ID: 34048) - Price: 20.00
# [15:35:15] EXTRACTED: 'Inovative Jumbo Junior Strawbe' (ID: 34050) - Price: 10.00
# [15:35:15] EXTRACTED: 'Peek Freans Heart Beats Biscui' (ID: 34055) - Price: 30.00
# [15:35:15] EXTRACTED: 'Peek Freans Gluco Teddy Milk C' (ID: 34057) - Price: 40.00
# [15:35:15] EXTRACTED: 'Peek Freans Cake Up Triple Cho' (ID: 34058) - Price: 50.00
# [15:35:15] EXTRACTED: 'Peek Freans Sooper Chocolate M' (ID: 34059) - Price: 30.00
# [15:35:16] EXTRACTED: 'Peek Freans Rio Strawberry Van' (ID: 34060) - Price: 40.00
# [15:35:16] EXTRACTED: 'Peek Freans Rio Strawberry Van' (ID: 34061) - Price: 30.00
# [15:35:16] EXTRACTED: 'Peek Freans Rio Strawberry Van' (ID: 34062) - Price: 20.00
# [15:35:16] EXTRACTED: 'Peek Freans Rio Doubl Choc Hal' (ID: 34063) - Price: 40.00
# [15:35:16] EXTRACTED: 'Peek Freans Rio Doubl Choc Sna' (ID: 34064) - Price: 20.00
# [15:35:17] EXTRACTED: 'Peek Freans Rio Doubl Choc Tic' (ID: 34065) - Price: 10.00
# [15:35:17] EXTRACTED: 'Peek Freans Gluco Half Roll' (ID: 34066) - Price: 40.00
# [15:35:17] EXTRACTED: 'Peek Freans Choco Licious Doub' (ID: 34069) - Price: 30.00
# [15:35:17] PAGE COMPLETE: Page 15: 20/33 products extracted
# [15:35:17] PAGINATION: Checking for page 16
# [15:35:17] PAGINATION: Moving to page 16
# [15:35:17] WAITING: Waiting for new page to load after pagination...
# [15:35:21] WAITING: Waiting for products to fully load on page 16
# [15:35:21] LOAD CHECK: Initial product container found
# [15:35:23] LOAD CHECK: 20 product images found
# [15:35:23] LOAD CHECK: 22 price elements found
# [15:35:24] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:24] PAGINATION: Successfully loaded page 16
# [15:35:26] PAGE START: Department 005 - Page 16
# [15:35:26] WAITING: Waiting for products to fully load on page 16
# [15:35:26] LOAD CHECK: Initial product container found
# [15:35:28] LOAD CHECK: 20 product images found
# [15:35:28] LOAD CHECK: 22 price elements found
# [15:35:29] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:29] PRODUCTS FOUND: Found 33 products on page 16
# [15:35:29] EXTRACTION FAILED: Card 1: No name element found
# [15:35:29] EXTRACTION FAILED: Card 2: No name element found
# [15:35:29] EXTRACTION FAILED: Card 3: No name element found
# [15:35:30] EXTRACTION FAILED: Card 4: No name element found
# [15:35:30] EXTRACTION FAILED: Card 5: No name element found
# [15:35:30] EXTRACTION FAILED: Card 6: No name element found
# [15:35:30] EXTRACTION FAILED: Card 7: No name element found
# [15:35:30] EXTRACTION FAILED: Card 8: No name element found
# [15:35:30] EXTRACTION FAILED: Card 9: No name element found
# [15:35:30] EXTRACTION FAILED: Card 10: No name element found
# [15:35:30] EXTRACTION FAILED: Card 11: No name element found
# [15:35:30] EXTRACTION FAILED: Card 12: No name element found
# [15:35:31] EXTRACTION FAILED: Card 13: No name element found
# [15:35:31] EXTRACTED: 'Lu Wheatable Sugar Free Snack' (ID: 34074) - Price: 50.00
# [15:35:31] EXTRACTED: 'Lu Tiger Bar Pack' (ID: 34075) - Price: 20.00
# [15:35:31] EXTRACTED: 'Lu Tiger Ticky Pack' (ID: 34076) - Price: 10.00
# [15:35:31] EXTRACTED: 'Lu Candi Original Bar Pack' (ID: 34077) - Price: 20.00
# [15:35:31] EXTRACTED: 'Lu Bakeri Nankhatai Biscuit' (ID: 34079) - Price: 40.00
# [15:35:32] EXTRACTED: 'Lu Oreo Chocolate Cream Half R' (ID: 34080) - Price: 40.00
# [15:35:32] EXTRACTED: 'Lu Prince Choco Jammies' (ID: 34084) - Price: 30.00
# [15:35:32] EXTRACTED: 'Inovative Haven Chocolate Cook' (ID: 34087) - Price: 200.00
# [15:35:32] EXTRACTED: 'Inovative Golden Lotus Cookies' (ID: 34088) - Price: 200.00
# [15:35:32] EXTRACTED: 'Bisconni Chocolate Chip Cookie' (ID: 34091) - Price: 20.00
# [15:35:33] EXTRACTED: 'Bisconni Flo Chocolate Van Cak' (ID: 34092) - Price: 10.00
# [15:35:33] EXTRACTED: 'Lu Oreo Chocolate Cream' (ID: 34126) - Price: 20.00
# [15:35:33] EXTRACTED: 'Mayfair Cafe Biscuit Half Roll' (ID: 34171) - Price: 30.00
# [15:35:33] EXTRACTED: 'Kolson Twich Classic Flavor 19' (ID: 34230) - Price: 20.00
# [15:35:33] EXTRACTED: 'Peek Freans Orig Choc Sandwich' (ID: 34252) - Price: 10.00
# [15:35:34] EXTRACTED: 'Kurkure Red Chilli Jhatka 78gm' (ID: 35319) - Price: 60.00
# [15:35:34] EXTRACTED: 'Lays Classic 30gm' (ID: 35398) - Price: 50.00
# [15:35:34] EXTRACTED: 'Lays Yogurt Herb 30gm' (ID: 35400) - Price: 50.00
# [15:35:34] EXTRACTED: 'Lays French Cheese 45gm' (ID: 35401) - Price: 70.00
# [15:35:34] EXTRACTED: 'Lays Wavy Taxas Bbq 70gm' (ID: 35402) - Price: 100.00
# [15:35:34] PAGE COMPLETE: Page 16: 20/33 products extracted
# [15:35:34] PAGINATION: Checking for page 17
# [15:35:34] PAGINATION: Moving to page 17
# [15:35:34] WAITING: Waiting for new page to load after pagination...
# [15:35:38] WAITING: Waiting for products to fully load on page 17
# [15:35:38] LOAD CHECK: Initial product container found
# [15:35:40] LOAD CHECK: 20 product images found
# [15:35:40] LOAD CHECK: 22 price elements found
# [15:35:41] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:41] PAGINATION: Successfully loaded page 17
# [15:35:43] PAGE START: Department 005 - Page 17
# [15:35:43] WAITING: Waiting for products to fully load on page 17
# [15:35:43] LOAD CHECK: Initial product container found
# [15:35:45] LOAD CHECK: 20 product images found
# [15:35:46] LOAD CHECK: 22 price elements found
# [15:35:47] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:47] PRODUCTS FOUND: Found 33 products on page 17
# [15:35:47] EXTRACTION FAILED: Card 1: No name element found
# [15:35:47] EXTRACTION FAILED: Card 2: No name element found
# [15:35:47] EXTRACTION FAILED: Card 3: No name element found
# [15:35:47] EXTRACTION FAILED: Card 4: No name element found
# [15:35:47] EXTRACTION FAILED: Card 5: No name element found
# [15:35:47] EXTRACTION FAILED: Card 6: No name element found
# [15:35:47] EXTRACTION FAILED: Card 7: No name element found
# [15:35:47] EXTRACTION FAILED: Card 8: No name element found
# [15:35:47] EXTRACTION FAILED: Card 9: No name element found
# [15:35:48] EXTRACTION FAILED: Card 10: No name element found
# [15:35:48] EXTRACTION FAILED: Card 11: No name element found
# [15:35:48] EXTRACTION FAILED: Card 12: No name element found
# [15:35:48] EXTRACTION FAILED: Card 13: No name element found
# [15:35:48] EXTRACTED: 'Lays Wavy Taxas Bbq 30gm' (ID: 35416) - Price: 50.00
# [15:35:48] EXTRACTED: 'Lays Classic 45gm' (ID: 35423) - Price: 70.00
# [15:35:48] EXTRACTED: 'Lays Wavy Taxas Bbq 45gm' (ID: 35442) - Price: 70.00
# [15:35:49] EXTRACTED: 'Lays Masala 45gm' (ID: 35444) - Price: 70.00
# [15:35:49] EXTRACTED: 'Lays Yogurt Herb 45gm' (ID: 35445) - Price: 70.00
# [15:35:49] EXTRACTED: 'Lays French Cheese 30gm' (ID: 35465) - Price: 50.00
# [15:35:49] EXTRACTED: 'Lays Masala 30gm' (ID: 35466) - Price: 50.00
# [15:35:49] EXTRACTED: 'Hilal Wispy Chocolate Wafer Ro' (ID: 35552) - Price: 20.00
# [15:35:50] EXTRACTED: 'Peek Freans Gluco Teddy Stb Ca' (ID: 35582) - Price: 40.00
# [15:35:50] EXTRACTED: 'Lu Prince Choc Biscuit Half Ro' (ID: 35601) - Price: 50.00
# [15:35:50] EXTRACTED: 'Foxs Berries Candy 90gm' (ID: 35636) - Price: 265.00
# [15:35:50] EXTRACTED: 'Bounty Chocolate 57gm' (ID: 35637) - Price: 225.00
# [15:35:50] EXTRACTED: 'Lu Tuc Salted Biscuit' (ID: 35646) - Price: 20.00
# [15:35:50] EXTRACTED: 'Cadbury Dairy Milk Chocolate M' (ID: 35789) - Price: 700.00
# [15:35:51] EXTRACTED: 'Lu Oreo Original' (ID: 35795) - Price: 50.00
# [15:35:51] EXTRACTED: 'Tiffany Delights Shortbreads 2' (ID: 35798) - Price: 1,395.00
# [15:35:51] EXTRACTED: 'Horlicks Chocolate Malted Drin' (ID: 35820) - Price: 945.00
# [15:35:51] EXTRACTED: 'Cadbury Drinking Chocolate 500' (ID: 35835) - Price: 2,395.00
# [15:35:51] EXTRACTED: 'Bisconni Eclipe Cream Biscuit' (ID: 35847) - Price: 30.00
# [15:35:52] EXTRACTED: 'Loacker Gardena Hazelnut Wafer' (ID: 36059) - Price: 265.00
# [15:35:52] PAGE COMPLETE: Page 17: 20/33 products extracted
# [15:35:52] PAGINATION: Checking for page 18
# [15:35:52] PAGINATION: Moving to page 18
# [15:35:52] WAITING: Waiting for new page to load after pagination...
# [15:35:56] WAITING: Waiting for products to fully load on page 18
# [15:35:56] LOAD CHECK: Initial product container found
# [15:35:58] LOAD CHECK: 20 product images found
# [15:35:58] LOAD CHECK: 22 price elements found
# [15:35:59] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:35:59] PAGINATION: Successfully loaded page 18
# [15:36:01] PAGE START: Department 005 - Page 18
# [15:36:01] WAITING: Waiting for products to fully load on page 18
# [15:36:01] LOAD CHECK: Initial product container found
# [15:36:03] LOAD CHECK: 20 product images found
# [15:36:03] LOAD CHECK: 22 price elements found
# [15:36:04] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:04] PRODUCTS FOUND: Found 33 products on page 18
# [15:36:04] EXTRACTION FAILED: Card 1: No name element found
# [15:36:04] EXTRACTION FAILED: Card 2: No name element found
# [15:36:04] EXTRACTION FAILED: Card 3: No name element found
# [15:36:04] EXTRACTION FAILED: Card 4: No name element found
# [15:36:04] EXTRACTION FAILED: Card 5: No name element found
# [15:36:04] EXTRACTION FAILED: Card 6: No name element found
# [15:36:05] EXTRACTION FAILED: Card 7: No name element found
# [15:36:05] EXTRACTION FAILED: Card 8: No name element found
# [15:36:05] EXTRACTION FAILED: Card 9: No name element found
# [15:36:05] EXTRACTION FAILED: Card 10: No name element found
# [15:36:05] EXTRACTION FAILED: Card 11: No name element found
# [15:36:05] EXTRACTION FAILED: Card 12: No name element found
# [15:36:05] EXTRACTION FAILED: Card 13: No name element found
# [15:36:05] EXTRACTED: 'Loacker Gardena Chocolate Wafe' (ID: 36060) - Price: 265.00
# [15:36:06] EXTRACTED: 'Track Crispy Strawberry Wafer' (ID: 36104) - Price: 330.00
# [15:36:06] EXTRACTED: 'Track Crispy Hazelnut Wafer 75' (ID: 36105) - Price: 335.00
# [15:36:06] EXTRACTED: 'Track Crispy Milky Wafer 75gm' (ID: 36106) - Price: 335.00
# [15:36:06] EXTRACTED: 'Track Crispy Orange Wafer 75gm' (ID: 36107) - Price: 355.00
# [15:36:06] EXTRACTED: 'Track Crispy Chocolate Wafer 7' (ID: 36108) - Price: 335.00
# [15:36:07] EXTRACTED: 'Track Crispy Hazelnut Wafer 1' (ID: 36112) - Price: 475.00
# [15:36:07] EXTRACTED: 'Track Crispy Vanilla Wafer 150' (ID: 36113) - Price: 475.00
# [15:36:07] EXTRACTED: 'Track Crispy Strawberry Wafer' (ID: 36114) - Price: 525.00
# [15:36:07] EXTRACTED: 'Track Crispy Milky Wafer 150gm' (ID: 36115) - Price: 430.00
# [15:36:08] EXTRACTED: 'Track Crispy Chocolate Wafer 1' (ID: 36116) - Price: 550.00
# [15:36:08] EXTRACTED: 'Track Crispy Orange Wafer 150g' (ID: 36117) - Price: 475.00
# [15:36:08] EXTRACTED: 'Lu Oreo Original Bar Pack 1pc' (ID: 36121) - Price: 10.00
# [15:36:08] EXTRACTED: 'Bisconni Delice Coconut Biscui' (ID: 36306) - Price: 30.00
# [15:36:08] EXTRACTED: 'Bisconni Digestive Sugar Free' (ID: 36307) - Price: 30.00
# [15:36:09] EXTRACTED: 'Yupi Gummi Foot Ball Jelly' (ID: 36373) - Price: 65.00
# [15:36:09] EXTRACTED: 'Yupi Dippy Gummy Sauce Jelly 2' (ID: 36374) - Price: 120.00
# [15:36:09] EXTRACTED: 'Yupi Korean Bbq Jelly 20gm' (ID: 36375) - Price: 100.00
# [15:36:09] EXTRACTED: 'Yupi Aquarium Jelly 8pcs 32gm' (ID: 36376) - Price: 94.00
# [15:36:10] EXTRACTED: 'Foxs Spring Tea Candy 90gm' (ID: 36378) - Price: 265.00
# [15:36:10] PAGE COMPLETE: Page 18: 20/33 products extracted
# [15:36:10] PAGINATION: Checking for page 19
# [15:36:10] PAGINATION: Moving to page 19
# [15:36:10] WAITING: Waiting for new page to load after pagination...
# [15:36:14] WAITING: Waiting for products to fully load on page 19
# [15:36:14] LOAD CHECK: Initial product container found
# [15:36:16] LOAD CHECK: 20 product images found
# [15:36:16] LOAD CHECK: 22 price elements found
# [15:36:17] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:17] PAGINATION: Successfully loaded page 19
# [15:36:19] PAGE START: Department 005 - Page 19
# [15:36:19] WAITING: Waiting for products to fully load on page 19
# [15:36:19] LOAD CHECK: Initial product container found
# [15:36:21] LOAD CHECK: 20 product images found
# [15:36:21] LOAD CHECK: 22 price elements found
# [15:36:22] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:22] PRODUCTS FOUND: Found 33 products on page 19
# [15:36:22] EXTRACTION FAILED: Card 1: No name element found
# [15:36:22] EXTRACTION FAILED: Card 2: No name element found
# [15:36:22] EXTRACTION FAILED: Card 3: No name element found
# [15:36:22] EXTRACTION FAILED: Card 4: No name element found
# [15:36:22] EXTRACTION FAILED: Card 5: No name element found
# [15:36:22] EXTRACTION FAILED: Card 6: No name element found
# [15:36:23] EXTRACTION FAILED: Card 7: No name element found
# [15:36:23] EXTRACTION FAILED: Card 8: No name element found
# [15:36:23] EXTRACTION FAILED: Card 9: No name element found
# [15:36:23] EXTRACTION FAILED: Card 10: No name element found
# [15:36:23] EXTRACTION FAILED: Card 11: No name element found
# [15:36:23] EXTRACTION FAILED: Card 12: No name element found
# [15:36:23] EXTRACTION FAILED: Card 13: No name element found
# [15:36:24] EXTRACTED: 'Foxs Fruity Mints Candy Tin 18' (ID: 36379) - Price: 695.00
# [15:36:24] EXTRACTED: 'Nestle Kitkat 2 Finger Origina' (ID: 36383) - Price: 145.00
# [15:36:24] EXTRACTED: 'You Creamiest Milk Chocolate 2' (ID: 36394) - Price: 30.00
# [15:36:24] EXTRACTED: 'Kolson Jam Hearts Lemon' (ID: 36413) - Price: 20.00
# [15:36:24] EXTRACTED: 'Hilal Cup Kake Celebration Spr' (ID: 36414) - Price: 20.00
# [15:36:25] EXTRACTED: 'Hilal Wispy Stw Wafer Rolls' (ID: 36416) - Price: 20.00
# [15:36:25] EXTRACTED: 'Hilal Wispy Chocolate Vanilla' (ID: 36417) - Price: 240.00
# [15:36:25] EXTRACTED: 'Hilal Wispy Stw Wafer Roll 24p' (ID: 36418) - Price: 240.00
# [15:36:25] EXTRACTED: 'Lu Cadbury Mini Finger Choc Bi' (ID: 36420) - Price: 20.00
# [15:36:26] EXTRACTED: 'Maxbar Peanuts Chocolate 142gm' (ID: 36452) - Price: 795.00
# [15:36:26] EXTRACTED: 'Horlicks Chocolate Powder 200g' (ID: 36476) - Price: 575.00
# [15:36:26] EXTRACTED: 'Hersheys Milk Chocolate 40gm' (ID: 36508) - Price: 365.00
# [15:36:27] EXTRACTED: 'Cadbury Perk Chocolate' (ID: 36561) - Price: 20.00
# [15:36:27] EXTRACTED: 'Cadbury Dairy Milk Crackle Cho' (ID: 36562) - Price: 115.00
# [15:36:27] EXTRACTED: 'Cadbury Dairy Milk Bubbly Bag' (ID: 36577) - Price: 775.00
# [15:36:27] EXTRACTED: 'Caramist Caramel Chocolate 51g' (ID: 36604) - Price: 130.00
# [15:36:28] EXTRACTED: 'Silvonta Caramel Peanut Chocol' (ID: 36605) - Price: 130.00
# [15:36:28] EXTRACTED: 'Lu Prince Biscuits' (ID: 36636) - Price: 40.00
# [15:36:28] EXTRACTED: 'Lays Paprika Potato Chips 21gm' (ID: 36642) - Price: 30.00
# [15:36:28] EXTRACTED: 'Danisa Butter Cookies 750gm' (ID: 36700) - Price: 3,750.00
# [15:36:28] PAGE COMPLETE: Page 19: 20/33 products extracted
# [15:36:28] PAGINATION: Checking for page 20
# [15:36:28] PAGINATION: Moving to page 20
# [15:36:28] WAITING: Waiting for new page to load after pagination...
# [15:36:32] WAITING: Waiting for products to fully load on page 20
# [15:36:32] LOAD CHECK: Initial product container found
# [15:36:34] LOAD CHECK: 20 product images found
# [15:36:34] LOAD CHECK: 22 price elements found
# [15:36:35] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:35] PAGINATION: Successfully loaded page 20
# [15:36:37] PAGE START: Department 005 - Page 20
# [15:36:37] WAITING: Waiting for products to fully load on page 20
# [15:36:37] LOAD CHECK: Initial product container found
# [15:36:39] LOAD CHECK: 20 product images found
# [15:36:39] LOAD CHECK: 22 price elements found
# [15:36:40] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:40] PRODUCTS FOUND: Found 33 products on page 20
# [15:36:41] EXTRACTION FAILED: Card 1: No name element found
# [15:36:41] EXTRACTION FAILED: Card 2: No name element found
# [15:36:41] EXTRACTION FAILED: Card 3: No name element found
# [15:36:41] EXTRACTION FAILED: Card 4: No name element found
# [15:36:41] EXTRACTION FAILED: Card 5: No name element found
# [15:36:41] EXTRACTION FAILED: Card 6: No name element found
# [15:36:41] EXTRACTION FAILED: Card 7: No name element found
# [15:36:41] EXTRACTION FAILED: Card 8: No name element found
# [15:36:41] EXTRACTION FAILED: Card 9: No name element found
# [15:36:42] EXTRACTION FAILED: Card 10: No name element found
# [15:36:42] EXTRACTION FAILED: Card 11: No name element found
# [15:36:42] EXTRACTION FAILED: Card 12: No name element found
# [15:36:42] EXTRACTION FAILED: Card 13: No name element found
# [15:36:42] EXTRACTED: 'Twix Chocolate 50gm' (ID: 36701) - Price: 230.00
# [15:36:42] EXTRACTED: 'American Kuisine Coconut Cream' (ID: 36705) - Price: 405.00
# [15:36:43] EXTRACTED: 'American Kuisine Strawberry Cr' (ID: 36706) - Price: 375.00
# [15:36:43] EXTRACTED: 'American Kuisine Vanilla Cream' (ID: 36707) - Price: 375.00
# [15:36:43] EXTRACTED: 'American Kuisine Milk Cream Wa' (ID: 36708) - Price: 375.00
# [15:36:43] EXTRACTED: 'Sweet Zone Cola Bottles Jelly' (ID: 36726) - Price: 450.00
# [15:36:43] EXTRACTED: 'Lu Prince Coco Choc Biscuit' (ID: 36763) - Price: 30.00
# [15:36:44] EXTRACTED: 'Yummy Gummy Watermelon Jelly J' (ID: 36824) - Price: 695.00
# [15:36:44] EXTRACTED: 'Vigos Compound Chocolate Candy' (ID: 36827) - Price: 1,140.00
# [15:36:44] EXTRACTED: 'Vigos Compound Chocolate Candy' (ID: 36828) - Price: 1,375.00
# [15:36:44] EXTRACTED: 'Kinder Bueno White Choc 2pc 39' (ID: 36839) - Price: 440.00
# [15:36:44] EXTRACTED: 'Bisconni Eclipse Cream Biscuit' (ID: 36864) - Price: 250.00
# [15:36:45] EXTRACTED: 'Mitchells Jubilee Chocolate 40' (ID: 36890) - Price: 40.00
# [15:36:45] EXTRACTED: 'Haribo Teeth Cilgin Disler Jel' (ID: 36892) - Price: 445.00
# [15:36:45] EXTRACTED: 'Haribo Likirr Jelly 70gm' (ID: 36893) - Price: 486.00
# [15:36:45] EXTRACTED: 'Haribo Starmix Jelly Pouch 160' (ID: 36895) - Price: 895.00
# [15:36:45] EXTRACTED: 'Inovative Fabulous Chocolate C' (ID: 36940) - Price: 195.00
# [15:36:45] EXTRACTED: 'Cheetos Bites Vegetable 34gm' (ID: 36978) - Price: 50.00
# [15:36:46] EXTRACTED: 'Toren Della Cookie Chocolate 5' (ID: 37015) - Price: 190.00
# [15:36:46] EXTRACTED: 'Toren Della Caramel Chocolate' (ID: 37016) - Price: 190.00
# [15:36:46] PAGE COMPLETE: Page 20: 20/33 products extracted
# [15:36:46] PAGINATION: Checking for page 21
# [15:36:46] PAGINATION: Moving to page 21
# [15:36:46] WAITING: Waiting for new page to load after pagination...
# [15:36:50] WAITING: Waiting for products to fully load on page 21
# [15:36:50] LOAD CHECK: Initial product container found
# [15:36:52] LOAD CHECK: 20 product images found
# [15:36:52] LOAD CHECK: 22 price elements found
# [15:36:53] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:53] PAGINATION: Successfully loaded page 21
# [15:36:55] PAGE START: Department 005 - Page 21
# [15:36:55] WAITING: Waiting for products to fully load on page 21
# [15:36:55] LOAD CHECK: Initial product container found
# [15:36:57] LOAD CHECK: 20 product images found
# [15:36:57] LOAD CHECK: 22 price elements found
# [15:36:58] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:36:58] PRODUCTS FOUND: Found 33 products on page 21
# [15:36:58] EXTRACTION FAILED: Card 1: No name element found
# [15:36:58] EXTRACTION FAILED: Card 2: No name element found
# [15:36:58] EXTRACTION FAILED: Card 3: No name element found
# [15:36:59] EXTRACTION FAILED: Card 4: No name element found
# [15:36:59] EXTRACTION FAILED: Card 5: No name element found
# [15:36:59] EXTRACTION FAILED: Card 6: No name element found
# [15:36:59] EXTRACTION FAILED: Card 7: No name element found
# [15:36:59] EXTRACTION FAILED: Card 8: No name element found
# [15:36:59] EXTRACTION FAILED: Card 9: No name element found
# [15:36:59] EXTRACTION FAILED: Card 10: No name element found
# [15:36:59] EXTRACTION FAILED: Card 11: No name element found
# [15:36:59] EXTRACTION FAILED: Card 12: No name element found
# [15:36:59] EXTRACTION FAILED: Card 13: No name element found
# [15:37:00] EXTRACTED: 'Shalimar Tulsi Elaichi Twist 4' (ID: 37061) - Price: 240.00
# [15:37:00] EXTRACTED: 'Pringles Bbq Bursting 158gm' (ID: 37091) - Price: 980.00
# [15:37:00] EXTRACTED: 'Lu Oreo Chocolate Cream' (ID: 37115) - Price: 50.00
# [15:37:00] EXTRACTED: 'Giggly Twisto Apple Stb Jelly' (ID: 37116) - Price: 250.00
# [15:37:00] EXTRACTED: 'Giggly Twisto Orange Lemon Jel' (ID: 37117) - Price: 250.00
# [15:37:01] EXTRACTED: 'Mayfair Amrood Candy Box 100pc' (ID: 37119) - Price: 200.00
# [15:37:01] EXTRACTED: 'Mayfair Fruit Gala Lychee Jumb' (ID: 37121) - Price: 200.00
# [15:37:01] EXTRACTED: 'Giggly Opus Caramel Chocolate' (ID: 37123) - Price: 100.00
# [15:37:01] EXTRACTED: 'Haribo Eksii Mix Jelly 70gm' (ID: 37124) - Price: 445.00
# [15:37:01] EXTRACTED: 'Cadbury Occasions Chocolate Ti' (ID: 37254) - Price: 1,500.00
# [15:37:01] EXTRACTED: 'Candyland Abc Jelly Party Pack' (ID: 37356) - Price: 50.00
# [15:37:02] EXTRACTED: 'Sweet Zone Fizzy Cola Jelly 90' (ID: 37359) - Price: 450.00
# [15:37:02] EXTRACTED: 'Bake Shake Cup Cake Strawberry' (ID: 37600) - Price: 20.00
# [15:37:02] EXTRACTED: 'Pringles Sour Cream Chips 40gm' (ID: 37664) - Price: 420.00
# [15:37:02] EXTRACTED: 'Pringles Cheddar Cheese Chips' (ID: 37665) - Price: 385.00
# [15:37:02] EXTRACTED: 'Pringles Original Chips 40gm' (ID: 37666) - Price: 420.00
# [15:37:03] EXTRACTED: 'Good Goodies Chocolate Cup Cak' (ID: 37720) - Price: 20.00
# [15:37:03] EXTRACTED: 'Good Goodies Double Chocolate' (ID: 37721) - Price: 20.00
# [15:37:03] EXTRACTED: 'Good Goodies Strawberry Cup Ca' (ID: 37722) - Price: 20.00
# [15:37:03] EXTRACTED: 'Mentos Spearmint Gum Jar 40pcs' (ID: 37743) - Price: 730.00
# [15:37:03] PAGE COMPLETE: Page 21: 20/33 products extracted
# [15:37:03] PAGINATION: Checking for page 22
# [15:37:03] PAGINATION: Moving to page 22
# [15:37:03] WAITING: Waiting for new page to load after pagination...
# [15:37:07] WAITING: Waiting for products to fully load on page 22
# [15:37:07] LOAD CHECK: Initial product container found
# [15:37:09] LOAD CHECK: 20 product images found
# [15:37:09] LOAD CHECK: 22 price elements found
# [15:37:10] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:37:10] PAGINATION: Successfully loaded page 22
# [15:37:12] PAGE START: Department 005 - Page 22
# [15:37:12] WAITING: Waiting for products to fully load on page 22
# [15:37:12] LOAD CHECK: Initial product container found
# [15:37:14] LOAD CHECK: 20 product images found
# [15:37:14] LOAD CHECK: 22 price elements found
# [15:37:15] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:37:15] PRODUCTS FOUND: Found 33 products on page 22
# [15:37:15] EXTRACTION FAILED: Card 1: No name element found
# [15:37:16] EXTRACTION FAILED: Card 2: No name element found
# [15:37:16] EXTRACTION FAILED: Card 3: No name element found
# [15:37:16] EXTRACTION FAILED: Card 4: No name element found
# [15:37:16] EXTRACTION FAILED: Card 5: No name element found
# [15:37:16] EXTRACTION FAILED: Card 6: No name element found
# [15:37:16] EXTRACTION FAILED: Card 7: No name element found
# [15:37:16] EXTRACTION FAILED: Card 8: No name element found
# [15:37:16] EXTRACTION FAILED: Card 9: No name element found
# [15:37:16] EXTRACTION FAILED: Card 10: No name element found
# [15:37:16] EXTRACTION FAILED: Card 11: No name element found
# [15:37:17] EXTRACTION FAILED: Card 12: No name element found
# [15:37:17] EXTRACTION FAILED: Card 13: No name element found
# [15:37:17] EXTRACTED: 'Snickers Chocolate 50.5gm' (ID: 37756) - Price: 244.00
# [15:37:17] EXTRACTED: 'Nestle Kitkat 4 Finger Chocola' (ID: 37757) - Price: 250.00
# [15:37:17] EXTRACTED: 'Sweet Zone Party Mix Jelly' (ID: 37888) - Price: 450.00
# [15:37:17] EXTRACTED: 'Sweet Zone Candy Blast 250gm' (ID: 37889) - Price: 620.00
# [15:37:18] EXTRACTED: 'Sweet Zone Candy Fruit Chews C' (ID: 37891) - Price: 620.00
# [15:37:18] EXTRACTED: 'Pringles Cheddar Sour Cream Bu' (ID: 37936) - Price: 980.00
# [15:37:18] EXTRACTED: 'Kraving Munch Orange Wafers 15' (ID: 37987) - Price: 380.00
# [15:37:18] EXTRACTED: 'Track Crispy Vanilla Wafer 75g' (ID: 38003) - Price: 335.00
# [15:37:18] EXTRACTED: 'Shalimar Tulsi Meva Dry Fruit' (ID: 38010) - Price: 240.00
# [15:37:19] EXTRACTED: 'Hum Tum Chocolate Pan Masala B' (ID: 38011) - Price: 240.00
# [15:37:19] EXTRACTED: 'Shalimar Palpal Chocolate Pan' (ID: 38012) - Price: 240.00
# [15:37:19] EXTRACTED: 'Shalimar Palpal Meetha Pan Box' (ID: 38013) - Price: 240.00
# [15:37:19] EXTRACTED: 'Shahi Aas Pass Chocolate Pan M' (ID: 38015) - Price: 240.00
# [15:37:19] EXTRACTED: 'Peek Freans Choco Licious Doub' (ID: 38027) - Price: 15.00
# [15:37:19] EXTRACTED: 'Cadbury Dairy Milk Almond Choc' (ID: 38079) - Price: 899.00
# [15:37:20] EXTRACTED: 'Cadbury Dairy Milk Choc 26gm' (ID: 38083) - Price: 99.00
# [15:37:20] EXTRACTED: 'Hersheys Special Dark Chocolat' (ID: 38091) - Price: 1,275.00
# [15:37:20] EXTRACTED: 'Ice Breakers Winter Green Chew' (ID: 38093) - Price: 595.00
# [15:37:20] EXTRACTED: 'Ice Breakers Sours Chew' (ID: 38096) - Price: 595.00
# [15:37:20] EXTRACTED: 'Cadbury Dairy Milk Chocolate 3' (ID: 38145) - Price: 350.00
# [15:37:20] PAGE COMPLETE: Page 22: 20/33 products extracted
# [15:37:20] PAGINATION: Checking for page 23
# [15:37:20] PAGINATION: Moving to page 23
# [15:37:21] WAITING: Waiting for new page to load after pagination...
# [15:37:25] WAITING: Waiting for products to fully load on page 23
# [15:37:25] LOAD CHECK: Initial product container found
# [15:37:27] LOAD CHECK: 20 product images found
# [15:37:27] LOAD CHECK: 22 price elements found
# [15:37:28] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:37:28] PAGINATION: Successfully loaded page 23
# [15:37:30] PAGE START: Department 005 - Page 23
# [15:37:30] WAITING: Waiting for products to fully load on page 23
# [15:37:30] LOAD CHECK: Initial product container found
# [15:37:32] LOAD CHECK: 20 product images found
# [15:37:32] LOAD CHECK: 22 price elements found
# [15:37:33] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:37:33] PRODUCTS FOUND: Found 33 products on page 23
# [15:37:33] EXTRACTION FAILED: Card 1: No name element found
# [15:37:33] EXTRACTION FAILED: Card 2: No name element found
# [15:37:33] EXTRACTION FAILED: Card 3: No name element found
# [15:37:33] EXTRACTION FAILED: Card 4: No name element found
# [15:37:33] EXTRACTION FAILED: Card 5: No name element found
# [15:37:33] EXTRACTION FAILED: Card 6: No name element found
# [15:37:33] EXTRACTION FAILED: Card 7: No name element found
# [15:37:34] EXTRACTION FAILED: Card 8: No name element found
# [15:37:34] EXTRACTION FAILED: Card 9: No name element found
# [15:37:34] EXTRACTION FAILED: Card 10: No name element found
# [15:37:34] EXTRACTION FAILED: Card 11: No name element found
# [15:37:34] EXTRACTION FAILED: Card 12: No name element found
# [15:37:34] EXTRACTION FAILED: Card 13: No name element found
# [15:37:34] EXTRACTED: 'Trident Cinnamon Twist 14stick' (ID: 38147) - Price: 330.00
# [15:37:34] EXTRACTED: 'Peek Freans Sooper Soft Cake P' (ID: 38152) - Price: 30.00
# [15:37:35] EXTRACTED: 'Danisa Cranberry Cookies 90gm' (ID: 38200) - Price: 525.00
# [15:37:35] EXTRACTED: 'Danisa Choco Cashew Cookies 90' (ID: 38201) - Price: 525.00
# [15:37:35] EXTRACTED: 'Danisa Currant Crunch Cookies' (ID: 38202) - Price: 525.00
# [15:37:35] EXTRACTED: 'Pringles Bbq Chips 40gm' (ID: 38267) - Price: 420.00
# [15:37:35] EXTRACTED: 'Bisconni Rite Biscuit' (ID: 38324) - Price: 10.00
# [15:37:36] EXTRACTED: 'Bisconni Rollies Swiss Cream C' (ID: 38325) - Price: 50.00
# [15:37:36] EXTRACTED: 'Lu Oreo Mini Chocolate' (ID: 38330) - Price: 20.00
# [15:37:36] EXTRACTED: 'Kolson Potato Sticks 60gm' (ID: 38361) - Price: 80.00
# [15:37:36] EXTRACTED: 'Bounty Miniatures Pouch 150gm' (ID: 38372) - Price: 1,394.00
# [15:37:36] EXTRACTED: 'Mars Miniatures Pouch 150gm' (ID: 38373) - Price: 1,441.00
# [15:37:36] EXTRACTED: 'Extra Spearmint Sugarfree Chew' (ID: 38375) - Price: 195.00
# [15:37:37] EXTRACTED: 'Extra Watermelon Sugarfree Che' (ID: 38376) - Price: 199.00
# [15:37:37] EXTRACTED: 'Cadbury Occasions Choc Box 86g' (ID: 38377) - Price: 500.00
# [15:37:37] EXTRACTED: 'Mentos Stb Sugarfree Chew Jar' (ID: 38386) - Price: 642.00
# [15:37:37] EXTRACTED: 'Foxs Assorted Coffee Candy 90g' (ID: 38388) - Price: 230.00
# [15:37:37] EXTRACTED: 'Cadbury Dairy Milk Chocolate I' (ID: 38431) - Price: 350.00
# [15:37:38] EXTRACTED: 'Calibar Milk Chocolate Bar 40g' (ID: 38447) - Price: 240.00
# [15:37:38] EXTRACTED: 'Kolson Snackers Hot Masala 18g' (ID: 38502) - Price: 30.00
# [15:37:38] PAGE COMPLETE: Page 23: 20/33 products extracted
# [15:37:38] PAGINATION: Checking for page 24
# [15:37:38] PAGINATION: Moving to page 24
# [15:37:38] WAITING: Waiting for new page to load after pagination...
# [15:37:42] WAITING: Waiting for products to fully load on page 24
# [15:37:42] LOAD CHECK: Initial product container found
# [15:37:44] LOAD CHECK: 20 product images found
# [15:37:44] LOAD CHECK: 22 price elements found
# [15:37:45] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:37:45] PAGINATION: Successfully loaded page 24
# [15:37:47] PAGE START: Department 005 - Page 24
# [15:37:47] WAITING: Waiting for products to fully load on page 24
# [15:37:47] LOAD CHECK: Initial product container found
# [15:37:49] LOAD CHECK: 20 product images found
# [15:37:49] LOAD CHECK: 22 price elements found
# [15:37:50] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:37:50] PRODUCTS FOUND: Found 33 products on page 24
# [15:37:50] EXTRACTION FAILED: Card 1: No name element found
# [15:37:50] EXTRACTION FAILED: Card 2: No name element found
# [15:37:50] EXTRACTION FAILED: Card 3: No name element found
# [15:37:50] EXTRACTION FAILED: Card 4: No name element found
# [15:37:51] EXTRACTION FAILED: Card 5: No name element found
# [15:37:51] EXTRACTION FAILED: Card 6: No name element found
# [15:37:51] EXTRACTION FAILED: Card 7: No name element found
# [15:37:51] EXTRACTION FAILED: Card 8: No name element found
# [15:37:51] EXTRACTION FAILED: Card 9: No name element found
# [15:37:51] EXTRACTION FAILED: Card 10: No name element found
# [15:37:51] EXTRACTION FAILED: Card 11: No name element found
# [15:37:51] EXTRACTION FAILED: Card 12: No name element found
# [15:37:51] EXTRACTION FAILED: Card 13: No name element found
# [15:37:52] EXTRACTED: 'Peek Freans Sooper Original' (ID: 38515) - Price: 360.00
# [15:37:52] EXTRACTED: 'Lays Masala 155gm' (ID: 38516) - Price: 100.00
# [15:37:52] EXTRACTED: 'Tropicana Slim Chocolate Hazel' (ID: 38524) - Price: 1,150.00
# [15:37:52] EXTRACTED: 'Tropicana Slim Hokkaido Cheese' (ID: 38528) - Price: 900.00
# [15:37:52] EXTRACTED: 'Tropicana Slim Korean Garlic B' (ID: 38529) - Price: 780.00
# [15:37:52] EXTRACTED: 'Peek Freans Sooper Biscuit Cho' (ID: 38561) - Price: 40.00
# [15:37:53] EXTRACTED: 'Mentos Tropical Gum Jar 40pcs' (ID: 38576) - Price: 699.00
# [15:37:53] EXTRACTED: 'Mentos Bubble Fresh Gum Jar 40' (ID: 38577) - Price: 699.00
# [15:37:53] EXTRACTED: 'Mentos Green Tea Chew Jar 50pc' (ID: 38578) - Price: 940.00
# [15:37:53] EXTRACTED: 'Peek Freans Sooper Original Ti' (ID: 38620) - Price: 10.00
# [15:37:54] EXTRACTED: 'Peek Freans Cake Up Double Cho' (ID: 38639) - Price: 20.00
# [15:37:54] EXTRACTED: 'Celebrations Bottle Chocolate' (ID: 38699) - Price: 3,960.00
# [15:37:54] EXTRACTED: 'Yupi Fruit Cocktails Jelly 14' (ID: 38712) - Price: 75.00
# [15:37:54] EXTRACTED: 'Yupi Gummi Pizza Jelly 15gm' (ID: 38713) - Price: 75.00
# [15:37:55] EXTRACTED: 'Bisconni Rite Chocolate Cream' (ID: 38736) - Price: 30.00
# [15:37:55] EXTRACTED: 'Smint Strawberry Chew Tin 25gm' (ID: 38743) - Price: 640.00
# [15:37:55] EXTRACTED: 'Smint Peppermint Chew Tin 25gm' (ID: 38745) - Price: 640.00
# [15:37:55] EXTRACTED: 'Smint Sweet Mint Chew Tin 25gm' (ID: 38746) - Price: 640.00
# [15:37:56] EXTRACTED: 'Inovative Digestive Original F' (ID: 38766) - Price: 250.00
# [15:37:56] EXTRACTED: 'Inovative Short Bread Butter C' (ID: 38767) - Price: 95.00
# [15:37:56] PAGE COMPLETE: Page 24: 20/33 products extracted
# [15:37:56] PAGINATION: Checking for page 25
# [15:37:56] PAGINATION: Moving to page 25
# [15:37:56] WAITING: Waiting for new page to load after pagination...
# [15:38:00] WAITING: Waiting for products to fully load on page 25
# [15:38:00] LOAD CHECK: Initial product container found
# [15:38:02] LOAD CHECK: 20 product images found
# [15:38:02] LOAD CHECK: 22 price elements found
# [15:38:03] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:38:03] PAGINATION: Successfully loaded page 25
# [15:38:05] PAGE START: Department 005 - Page 25
# [15:38:05] WAITING: Waiting for products to fully load on page 25
# [15:38:05] LOAD CHECK: Initial product container found
# [15:38:07] LOAD CHECK: 20 product images found
# [15:38:07] LOAD CHECK: 22 price elements found
# [15:38:08] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:38:08] PRODUCTS FOUND: Found 33 products on page 25
# [15:38:08] EXTRACTION FAILED: Card 1: No name element found
# [15:38:08] EXTRACTION FAILED: Card 2: No name element found
# [15:38:08] EXTRACTION FAILED: Card 3: No name element found
# [15:38:08] EXTRACTION FAILED: Card 4: No name element found
# [15:38:09] EXTRACTION FAILED: Card 5: No name element found
# [15:38:09] EXTRACTION FAILED: Card 6: No name element found
# [15:38:09] EXTRACTION FAILED: Card 7: No name element found
# [15:38:09] EXTRACTION FAILED: Card 8: No name element found
# [15:38:09] EXTRACTION FAILED: Card 9: No name element found
# [15:38:09] EXTRACTION FAILED: Card 10: No name element found
# [15:38:09] EXTRACTION FAILED: Card 11: No name element found
# [15:38:09] EXTRACTION FAILED: Card 12: No name element found
# [15:38:09] EXTRACTION FAILED: Card 13: No name element found
# [15:38:10] EXTRACTED: 'Inovative Biscoffi Crackers 35' (ID: 38768) - Price: 50.00
# [15:38:10] EXTRACTED: 'Kurkure Mirchili Chana Chaat 2' (ID: 38771) - Price: 30.00
# [15:38:10] EXTRACTED: 'Ovaltine Choc Cookies Box 40gm' (ID: 38782) - Price: 520.00
# [15:38:10] EXTRACTED: 'Ovaltine Chocolate Malt Wafers' (ID: 38783) - Price: 540.00
# [15:38:11] EXTRACTED: 'Ovaltine Chocolate Malt Biscui' (ID: 38784) - Price: 499.00
# [15:38:11] EXTRACTED: 'Ovaltine Malty Bites Wafer P.b' (ID: 38785) - Price: 450.00
# [15:38:11] EXTRACTED: 'Softmints Ice Family Pack 132g' (ID: 38868) - Price: 145.00
# [15:38:11] EXTRACTED: 'Peek Freans Gluco Energy Tick' (ID: 38871) - Price: 10.00
# [15:38:12] EXTRACTED: 'Peek Freans Cake Up Caramel Ca' (ID: 38876) - Price: 20.00
# [15:38:12] EXTRACTED: 'Lays Wavy Yogurt Herb 30gm' (ID: 38907) - Price: 50.00
# [15:38:12] EXTRACTED: 'Lays Wavy Yogurt Herb 45gm' (ID: 38908) - Price: 70.00
# [15:38:12] EXTRACTED: 'Lays Wavy Yogurt Herb 16gm' (ID: 38909) - Price: 30.00
# [15:38:12] EXTRACTED: 'Kurkure Chatpati Dahi Papri 41' (ID: 38910) - Price: 50.00
# [15:38:13] EXTRACTED: 'Kurkure Chatpati Dahi Papri 21' (ID: 38911) - Price: 30.00
# [15:38:13] EXTRACTED: 'Lu Cadbury Cookies Biscuit 25g' (ID: 38912) - Price: 40.00
# [15:38:13] EXTRACTED: 'Wrigleys Extra Apple Chew 14gm' (ID: 38923) - Price: 199.00
# [15:38:13] EXTRACTED: 'Orbit Strawberry Chew' (ID: 38924) - Price: 135.00
# [15:38:14] EXTRACTED: 'Orbit Peppermint Chew' (ID: 38925) - Price: 135.00
# [15:38:14] EXTRACTED: 'Orbit Winter Fresh Chew' (ID: 38926) - Price: 135.00
# [15:38:14] EXTRACTED: 'Orbit White Bubble Mint Chew' (ID: 38927) - Price: 135.00
# [15:38:14] PAGE COMPLETE: Page 25: 20/33 products extracted
# [15:38:14] PAGINATION: Checking for page 26
# [15:38:14] PAGINATION: No next button found
# [15:38:14] DEPARTMENT COMPLETE: No more pages after page 25
# ────────────────────────────────────────────────────────────────────────────────
# DEPARTMENT 005 COMPLETED!
# Total products: 500
# Time taken: 438.64 seconds
# ────────────────────────────────────────────────────────────────────────────────
# [15:38:14] PAGE CLOSED: Department 005 browser page closed
# [15:38:14] PAUSING: Waiting 5 seconds before next department...
#
# OVERALL PROGRESS: Department 6/7
#
# ================================================================================
# STARTING DEPARTMENT 006
# URL: https://www.rahimstore.com/department/006
# ================================================================================
# [15:38:19] NAVIGATING: Loading https://www.rahimstore.com/department/006 (waiting for full load)...
# [15:38:20] PAGE LOADED: Initial page loaded, waiting for full content...
# [15:38:20] WAITING: Waiting for products to fully load on page 1
# [15:38:21] LOAD CHECK: Initial product container found
# [15:38:23] LOAD CHECK: 20 product images found
# [15:38:23] LOAD CHECK: 22 price elements found
# [15:38:24] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:38:24] PAGE START: Department 006 - Page 1
# [15:38:24] WAITING: Waiting for products to fully load on page 1
# [15:38:24] LOAD CHECK: Initial product container found
# [15:38:26] LOAD CHECK: 20 product images found
# [15:38:26] LOAD CHECK: 22 price elements found
# [15:38:27] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:38:27] PRODUCTS FOUND: Found 33 products on page 1
# [15:38:27] EXTRACTION FAILED: Card 1: No name element found
# [15:38:27] EXTRACTION FAILED: Card 2: No name element found
# [15:38:27] EXTRACTION FAILED: Card 3: No name element found
# [15:38:27] EXTRACTION FAILED: Card 4: No name element found
# [15:38:27] EXTRACTION FAILED: Card 5: No name element found
# [15:38:27] EXTRACTION FAILED: Card 6: No name element found
# [15:38:28] EXTRACTION FAILED: Card 7: No name element found
# [15:38:28] EXTRACTION FAILED: Card 8: No name element found
# [15:38:28] EXTRACTION FAILED: Card 9: No name element found
# [15:38:28] EXTRACTION FAILED: Card 10: No name element found
# [15:38:28] EXTRACTION FAILED: Card 11: No name element found
# [15:38:28] EXTRACTION FAILED: Card 12: No name element found
# [15:38:28] EXTRACTION FAILED: Card 13: No name element found
# [15:38:29] EXTRACTED: 'Bonus Active 1kg' (ID: 410) - Price: 295.00
# [15:38:29] EXTRACTED: 'Bonus Tristar 1kg' (ID: 413) - Price: 219.99
# [15:38:29] EXTRACTED: 'Express Power 1kg' (ID: 419) - Price: 390.00
# [15:38:29] EXTRACTED: 'Surf Excel Matic Top Load 1kg' (ID: 719) - Price: 695.02
# [15:38:30] EXTRACTED: 'Brite Maximum Power 2kg' (ID: 724) - Price: 1,045.00
# [15:38:30] EXTRACTED: 'Brite Maximum Power 500gm' (ID: 725) - Price: 275.00
# [15:38:30] EXTRACTED: 'Comfort Morning Fresh Fabric C' (ID: 732) - Price: 240.00
# [15:38:30] EXTRACTED: 'Brite Maximum Power 3kg' (ID: 734) - Price: 1,564.96
# [15:38:31] EXTRACTED: 'Sufi Super Soap 4pcs 600gm' (ID: 1139) - Price: 342.00
# [15:38:31] EXTRACTED: 'Sufi Spacial Washing Soap 1kg' (ID: 1142) - Price: 499.00
# [15:38:31] EXTRACTED: 'Number 1 Washing Powder 1kg' (ID: 1145) - Price: 205.00
# [15:38:31] EXTRACTED: 'Sufi Soap Vermicelli 1kg' (ID: 1151) - Price: 520.00
# [15:38:31] EXTRACTED: 'Max Soft Feel Dishwash Liquid' (ID: 1155) - Price: 375.00
# [15:38:32] EXTRACTED: 'Lemon Max Dish Wash Yellow 75' (ID: 1169) - Price: 385.00
# [15:38:32] EXTRACTED: 'Lemon Max Anti Bacterial Liqui' (ID: 1172) - Price: 315.00
# [15:38:32] EXTRACTED: 'Lemon Max Liquid Ultra Green 5' (ID: 1175) - Price: 435.01
# [15:38:32] EXTRACTED: 'Lemon Max Lemon Dish Wash Liqu' (ID: 1176) - Price: 160.00
# [15:38:32] EXTRACTED: 'Lemon Max Dish Wash Yellow Pas' (ID: 1177) - Price: 230.00
# [15:38:33] EXTRACTED: 'Lemon Max Liquid Anti Bacteria' (ID: 1179) - Price: 265.00
# [15:38:33] EXTRACTED: 'Lemon Max Long Bar 265gm' (ID: 1186) - Price: 80.00
# [15:38:33] PAGE COMPLETE: Page 1: 20/33 products extracted
# [15:38:33] PAGINATION: Checking for page 2
# [15:38:33] PAGINATION: Moving to page 2
# [15:38:33] WAITING: Waiting for new page to load after pagination...
# [15:38:37] WAITING: Waiting for products to fully load on page 2
# [15:38:37] LOAD CHECK: Initial product container found
# [15:38:39] LOAD CHECK: 20 product images found
# [15:38:39] LOAD CHECK: 22 price elements found
# [15:38:40] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:38:40] PAGINATION: Successfully loaded page 2
# [15:38:42] PAGE START: Department 006 - Page 2
# [15:38:42] WAITING: Waiting for products to fully load on page 2
# [15:38:42] LOAD CHECK: Initial product container found
# [15:38:44] LOAD CHECK: 20 product images found
# [15:38:44] LOAD CHECK: 22 price elements found
# [15:38:45] LOAD COMPLETE: All products fully loaded and ready for scraping
# [15:38:45] PRODUCTS FOUND: Found 33 products on page 2
# [15:38:45] EXTRACTION FAILED: Card 1: No name element found
# [15:38:45] EXTRACTION FAILED: Card 2: No name element found
# ...
# [16:02:22] EXTRACTED: 'Fogg Fresh Woody Body Spray 12' (ID: 38488) - Price: 899.00
# [16:02:22] EXTRACTED: 'Bentley For Men Eau Toilette 1' (ID: 38568) - Price: 9,000.00
# [16:02:22] EXTRACTED: 'Bentley Absolute Black Men Par' (ID: 38569) - Price: 10,850.00
# [16:02:22] EXTRACTED: 'Bentley Intense For Men Edp 10' (ID: 38570) - Price: 10,950.00
# [16:02:23] EXTRACTED: 'Bentley Infinite Rush White To' (ID: 38571) - Price: 10,250.00
# [16:02:23] EXTRACTED: 'Bentley Infinite Eau Toilette' (ID: 38572) - Price: 9,295.00
# [16:02:23] EXTRACTED: 'Bentley Momentum Eau Toilette' (ID: 38573) - Price: 9,650.00
# [16:02:23] EXTRACTED: 'Enchanteur Whitening Romantic' (ID: 38591) - Price: 490.00
# [16:02:23] EXTRACTED: 'Nike Vibes Men Body Spray 200m' (ID: 38604) - Price: 995.00
# [16:02:23] EXTRACTED: 'Nike Ginger Tonic Man Body Spr' (ID: 38605) - Price: 995.00
# [16:02:24] EXTRACTED: 'Nike Yummy Musk Body Spray 200' (ID: 38606) - Price: 995.00
# [16:02:24] EXTRACTED: 'She Is Cool Roll On 50ml' (ID: 38607) - Price: 470.00
# [16:02:24] PAGE COMPLETE: Page 57: 20/33 products extracted
# [16:02:24] PAGINATION: Checking for page 58
# [16:02:24] PAGINATION: Moving to page 58
# [16:02:24] WAITING: Waiting for new page to load after pagination...
# [16:02:28] WAITING: Waiting for products to fully load on page 58
# [16:02:28] LOAD CHECK: Initial product container found
# [16:02:30] LOAD CHECK: 20 product images found
# [16:02:30] LOAD CHECK: 22 price elements found
# [16:02:31] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:02:31] PAGINATION: Successfully loaded page 58
# [16:02:33] PAGE START: Department 007 - Page 58
# [16:02:33] WAITING: Waiting for products to fully load on page 58
# [16:02:33] LOAD CHECK: Initial product container found
# [16:02:35] LOAD CHECK: 20 product images found
# [16:02:35] LOAD CHECK: 22 price elements found
# [16:02:36] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:02:36] PRODUCTS FOUND: Found 33 products on page 58
# [16:02:36] EXTRACTION FAILED: Card 1: No name element found
# [16:02:36] EXTRACTION FAILED: Card 2: No name element found
# [16:02:36] EXTRACTION FAILED: Card 3: No name element found
# [16:02:36] EXTRACTION FAILED: Card 4: No name element found
# [16:02:37] EXTRACTION FAILED: Card 5: No name element found
# [16:02:37] EXTRACTION FAILED: Card 6: No name element found
# [16:02:37] EXTRACTION FAILED: Card 7: No name element found
# [16:02:37] EXTRACTION FAILED: Card 8: No name element found
# [16:02:37] EXTRACTION FAILED: Card 9: No name element found
# [16:02:37] EXTRACTION FAILED: Card 10: No name element found
# [16:02:37] EXTRACTION FAILED: Card 11: No name element found
# [16:02:37] EXTRACTION FAILED: Card 12: No name element found
# [16:02:37] EXTRACTION FAILED: Card 13: No name element found
# [16:02:38] EXTRACTED: 'She Is Sexy Roll On 50ml' (ID: 38608) - Price: 470.00
# [16:02:38] EXTRACTED: 'She Is Love Roll On 50ml' (ID: 38609) - Price: 470.00
# [16:02:38] EXTRACTED: 'She Is Sweet Roll On 50ml' (ID: 38610) - Price: 470.00
# [16:02:38] EXTRACTED: 'She Is Pretty Roll On 50ml' (ID: 38611) - Price: 470.00
# [16:02:38] EXTRACTED: 'She Is Angel Roll On 50ml' (ID: 38612) - Price: 470.00
# [16:02:39] EXTRACTED: 'She Is Clubber Roll On 50ml' (ID: 38613) - Price: 470.00
# [16:02:39] EXTRACTED: 'She Is Fun Roll On 50ml' (ID: 38614) - Price: 470.00
# [16:02:39] EXTRACTED: 'Calvin Klein Eternity Air Men' (ID: 38625) - Price: 9,750.00
# [16:02:39] EXTRACTED: 'Guy Karoche Drakkar Intense Ed' (ID: 38626) - Price: 8,850.00
# [16:02:39] EXTRACTED: 'Ferragamo Black Homme Edt 100m' (ID: 38627) - Price: 10,950.00
# [16:02:39] EXTRACTED: 'Hype Berry Berry Fruity Body S' (ID: 38630) - Price: 550.00
# [16:02:40] EXTRACTED: 'Hype Fruit Frenzy Body Spray 1' (ID: 38631) - Price: 550.00
# [16:02:40] EXTRACTED: 'Hype Feelin Peachy Body Spray' (ID: 38632) - Price: 550.00
# [16:02:40] EXTRACTED: 'Hype Candy Apple Body Spray 15' (ID: 38633) - Price: 550.00
# [16:02:40] EXTRACTED: 'Hype Dare To Spice Body Spray' (ID: 38634) - Price: 600.00
# [16:02:40] EXTRACTED: 'Hype Bold & Brilliant Body Spr' (ID: 38635) - Price: 600.00
# [16:02:41] EXTRACTED: 'Hype Beachy Vibes Body Spray 1' (ID: 38636) - Price: 600.00
# [16:02:41] EXTRACTED: 'Hype Neon Night Body Spray 150' (ID: 38637) - Price: 600.00
# [16:02:41] EXTRACTED: 'Nivea Men Black White Stick 72' (ID: 38648) - Price: 950.00
# [16:02:41] EXTRACTED: 'Nivea Men Fresh Active Stick 4' (ID: 38649) - Price: 950.00
# [16:02:41] PAGE COMPLETE: Page 58: 20/33 products extracted
# [16:02:41] PAGINATION: Checking for page 59
# [16:02:41] PAGINATION: Moving to page 59
# [16:02:41] WAITING: Waiting for new page to load after pagination...
# [16:02:45] WAITING: Waiting for products to fully load on page 59
# [16:02:45] LOAD CHECK: Initial product container found
# [16:02:47] LOAD CHECK: 20 product images found
# [16:02:47] LOAD CHECK: 22 price elements found
# [16:02:48] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:02:48] PAGINATION: Successfully loaded page 59
# [16:02:50] PAGE START: Department 007 - Page 59
# [16:02:50] WAITING: Waiting for products to fully load on page 59
# [16:02:50] LOAD CHECK: Initial product container found
# [16:02:52] LOAD CHECK: 20 product images found
# [16:02:52] LOAD CHECK: 22 price elements found
# [16:02:53] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:02:53] PRODUCTS FOUND: Found 33 products on page 59
# [16:02:53] EXTRACTION FAILED: Card 1: No name element found
# [16:02:53] EXTRACTION FAILED: Card 2: No name element found
# [16:02:54] EXTRACTION FAILED: Card 3: No name element found
# [16:02:54] EXTRACTION FAILED: Card 4: No name element found
# [16:02:54] EXTRACTION FAILED: Card 5: No name element found
# [16:02:54] EXTRACTION FAILED: Card 6: No name element found
# [16:02:54] EXTRACTION FAILED: Card 7: No name element found
# [16:02:54] EXTRACTION FAILED: Card 8: No name element found
# [16:02:54] EXTRACTION FAILED: Card 9: No name element found
# [16:02:54] EXTRACTION FAILED: Card 10: No name element found
# [16:02:54] EXTRACTION FAILED: Card 11: No name element found
# [16:02:55] EXTRACTION FAILED: Card 12: No name element found
# [16:02:55] EXTRACTION FAILED: Card 13: No name element found
# [16:02:55] EXTRACTED: 'Nivea Men Fresh Kick Stick 48h' (ID: 38650) - Price: 950.00
# [16:02:55] EXTRACTED: 'Nivea Fresh Natural Stick 48h' (ID: 38651) - Price: 950.00
# [16:02:55] EXTRACTED: 'Nivea Fresh Flower Stick 48h 5' (ID: 38652) - Price: 950.00
# [16:02:55] EXTRACTED: 'Nivea Black White Silky Smooth' (ID: 38654) - Price: 499.00
# [16:02:56] EXTRACTED: 'Bvlgari Rose Goldea Parfum 90m' (ID: 38657) - Price: 30,500.00
# [16:02:56] EXTRACTED: 'Ferragamo Silver Homme Toilett' (ID: 38658) - Price: 9,600.00
# [16:02:56] EXTRACTED: 'Ferragamo Free Time Edt 100ml' (ID: 38659) - Price: 10,350.00
# [16:02:56] EXTRACTED: 'Joop Go Edt Perfume 100ml' (ID: 38660) - Price: 7,350.00
# [16:02:56] EXTRACTED: 'Chanel Allure Superlegera Parf' (ID: 38675) - Price: 53,950.00
# [16:02:56] EXTRACTED: 'Milano Prada Intense Homme Par' (ID: 38676) - Price: 41,550.00
# [16:02:57] EXTRACTED: 'Luna Rossa Sports Prada Toilet' (ID: 38677) - Price: 28,250.00
# [16:02:57] EXTRACTED: 'Fantasy Britney Spears Parfum' (ID: 38678) - Price: 7,750.00
# [16:02:57] EXTRACTED: 'Burberry Brit Sheer Her Toilet' (ID: 38791) - Price: 12,480.00
# [16:02:57] EXTRACTED: 'Dunhill Icon Racing Men Parfum' (ID: 38792) - Price: 13,450.00
# [16:02:57] EXTRACTED: 'Dunhill Custom Men Edt 100ml' (ID: 38793) - Price: 7,695.00
# [16:02:58] EXTRACTED: 'Bvlgari Man Wood Neroli Parfum' (ID: 38794) - Price: 19,495.00
# [16:02:58] EXTRACTED: 'Sauvage Dior Parfum Blue Box 1' (ID: 38795) - Price: 49,500.00
# [16:02:58] EXTRACTED: 'Thomas Kosmala No.4 Parfum 100' (ID: 38796) - Price: 27,495.00
# [16:02:58] EXTRACTED: 'Issey Miyake Vetiver Vetyver T' (ID: 38799) - Price: 14,900.00
# [16:02:58] EXTRACTED: '212 Vip Black I Ny Men Parfum' (ID: 38800) - Price: 22,800.00
# [16:02:58] PAGE COMPLETE: Page 59: 20/33 products extracted
# [16:02:58] PAGINATION: Checking for page 60
# [16:02:58] PAGINATION: Moving to page 60
# [16:02:58] WAITING: Waiting for new page to load after pagination...
# [16:03:02] WAITING: Waiting for products to fully load on page 60
# [16:03:02] LOAD CHECK: Initial product container found
# [16:03:04] LOAD CHECK: 20 product images found
# [16:03:05] LOAD CHECK: 22 price elements found
# [16:03:06] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:03:06] PAGINATION: Successfully loaded page 60
# [16:03:08] PAGE START: Department 007 - Page 60
# [16:03:08] WAITING: Waiting for products to fully load on page 60
# [16:03:08] LOAD CHECK: Initial product container found
# [16:03:10] LOAD CHECK: 20 product images found
# [16:03:10] LOAD CHECK: 22 price elements found
# [16:03:11] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:03:11] PRODUCTS FOUND: Found 33 products on page 60
# [16:03:11] EXTRACTION FAILED: Card 1: No name element found
# [16:03:11] EXTRACTION FAILED: Card 2: No name element found
# [16:03:11] EXTRACTION FAILED: Card 3: No name element found
# [16:03:11] EXTRACTION FAILED: Card 4: No name element found
# [16:03:11] EXTRACTION FAILED: Card 5: No name element found
# [16:03:11] EXTRACTION FAILED: Card 6: No name element found
# [16:03:11] EXTRACTION FAILED: Card 7: No name element found
# [16:03:11] EXTRACTION FAILED: Card 8: No name element found
# [16:03:12] EXTRACTION FAILED: Card 9: No name element found
# [16:03:12] EXTRACTION FAILED: Card 10: No name element found
# [16:03:12] EXTRACTION FAILED: Card 11: No name element found
# [16:03:12] EXTRACTION FAILED: Card 12: No name element found
# [16:03:12] EXTRACTION FAILED: Card 13: No name element found
# [16:03:12] EXTRACTED: 'Issey Miyake Extreme Eau Toile' (ID: 38801) - Price: 13,500.00
# [16:03:12] EXTRACTED: 'Issey Miyake Wood Wood Parfum' (ID: 38802) - Price: 16,850.00
# [16:03:13] EXTRACTED: 'Davidoff Cool Water Sea Rose W' (ID: 38803) - Price: 8,995.00
# [16:03:13] EXTRACTED: 'Galaxy Avalanche Body Spray 20' (ID: 38814) - Price: 690.00
# [16:03:13] EXTRACTED: 'Galaxy Accent Body Spray 200ml' (ID: 38815) - Price: 690.00
# [16:03:13] EXTRACTED: 'Galaxy Your Way Body Spray 200' (ID: 38816) - Price: 795.00
# [16:03:13] EXTRACTED: 'Galaxy Centigrade Body Spray 2' (ID: 38817) - Price: 690.00
# [16:03:13] EXTRACTED: 'Galaxy Blue Blood Body Spray 2' (ID: 38818) - Price: 690.00
# [16:03:14] EXTRACTED: 'Galaxy Homme Legends Body Spra' (ID: 38819) - Price: 795.00
# [16:03:14] EXTRACTED: 'Galaxy Black Stone Body Spray' (ID: 38820) - Price: 714.00
# [16:03:14] EXTRACTED: 'Galaxy Icon Femme Body Spray 2' (ID: 38821) - Price: 795.00
# [16:03:14] EXTRACTED: 'Galaxy Homme Savage Body Spray' (ID: 38822) - Price: 795.00
# [16:03:14] EXTRACTED: 'Galaxy Epho Femme Body Spray 2' (ID: 38823) - Price: 795.00
# [16:03:15] EXTRACTED: 'Galaxy Blue Homme Body Spray 2' (ID: 38824) - Price: 690.00
# [16:03:15] EXTRACTED: 'Nike Chic Cool Body Spray 200m' (ID: 38842) - Price: 1,050.00
# [16:03:15] EXTRACTED: 'Nike Floral Boom Body Spray 20' (ID: 38843) - Price: 995.00
# [16:03:15] EXTRACTED: 'Nike Sun Wood Body Spray 200ml' (ID: 38844) - Price: 1,050.00
# [16:03:16] EXTRACTED: 'Nike Blue Bamboo Body Spray 20' (ID: 38845) - Price: 1,050.00
# [16:03:16] EXTRACTED: 'Nike Up Or Down Men Body Spray' (ID: 38846) - Price: 995.00
# [16:03:16] EXTRACTED: 'Colour Me Indogo Body Spray 15' (ID: 38847) - Price: 1,033.00
# [16:03:16] PAGE COMPLETE: Page 60: 20/33 products extracted
# [16:03:16] PAGINATION: Checking for page 61
# [16:03:16] PAGINATION: Moving to page 61
# [16:03:16] WAITING: Waiting for new page to load after pagination...
# [16:03:20] WAITING: Waiting for products to fully load on page 61
# [16:03:20] LOAD CHECK: Initial product container found
# [16:03:22] LOAD CHECK: 20 product images found
# [16:03:22] LOAD CHECK: 22 price elements found
# [16:03:23] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:03:23] PAGINATION: Successfully loaded page 61
# [16:03:25] PAGE START: Department 007 - Page 61
# [16:03:25] WAITING: Waiting for products to fully load on page 61
# [16:03:25] LOAD CHECK: Initial product container found
# [16:03:27] LOAD CHECK: 20 product images found
# [16:03:27] LOAD CHECK: 22 price elements found
# [16:03:28] LOAD COMPLETE: All products fully loaded and ready for scraping
# [16:03:28] PRODUCTS FOUND: Found 33 products on page 61
# [16:03:28] EXTRACTION FAILED: Card 1: No name element found
# [16:03:28] EXTRACTION FAILED: Card 2: No name element found
# [16:03:29] EXTRACTION FAILED: Card 3: No name element found
# [16:03:29] EXTRACTION FAILED: Card 4: No name element found
# [16:03:29] EXTRACTION FAILED: Card 5: No name element found
# [16:03:29] EXTRACTION FAILED: Card 6: No name element found
# [16:03:29] EXTRACTION FAILED: Card 7: No name element found
# [16:03:29] EXTRACTION FAILED: Card 8: No name element found
# [16:03:29] EXTRACTION FAILED: Card 9: No name element found
# [16:03:29] EXTRACTION FAILED: Card 10: No name element found
# [16:03:29] EXTRACTION FAILED: Card 11: No name element found
# [16:03:30] EXTRACTION FAILED: Card 12: No name element found
# [16:03:30] EXTRACTION FAILED: Card 13: No name element found
# [16:03:30] EXTRACTED: 'Colour Me Coral Body Spray 150' (ID: 38848) - Price: 1,050.00
# [16:03:30] EXTRACTED: 'Colour Me Aqua Body Spray 150m' (ID: 38849) - Price: 1,050.00
# [16:03:30] EXTRACTED: 'Colour Me Dark Green Body Spra' (ID: 38850) - Price: 1,050.00
# [16:03:31] EXTRACTED: 'Colour Me Dark Red Body Spray' (ID: 38851) - Price: 999.00
# [16:03:31] EXTRACTED: 'Colour Me Colours Body Spray 1' (ID: 38877) - Price: 999.00
# [16:03:31] EXTRACTED: 'Ferrori Sports 08 Body Spray 1' (ID: 38881) - Price: 349.00
# [16:03:31] EXTRACTED: 'Ferrori Sports 09 Body Spray 1' (ID: 38882) - Price: 315.00
# [16:03:31] EXTRACTED: 'Ferrori Sports 10 Body Spray 1' (ID: 38883) - Price: 360.00
# [16:03:32] EXTRACTED: 'Lattafa Ana Abiyedh Rouge Body' (ID: 38888) - Price: 650.00
# [16:03:32] EXTRACTED: 'Lattafa Ajwad Gold Body Spray' (ID: 38889) - Price: 680.00
# [16:03:32] EXTRACTED: 'Lattafa Eclaire Body Spray 200' (ID: 38890) - Price: 735.00
# [16:03:32] EXTRACTED: 'Lattafa Qaed Al Fursan Body Sp' (ID: 38891) - Price: 650.00
# [16:03:33] EXTRACTED: 'Lattafa Luxe Raed Body Spray 2' (ID: 38892) - Price: 680.00
# [16:03:33] EXTRACTED: 'Old Spice Nightpanther Stick 5' (ID: 38940) - Price: 899.00
# [16:03:33] EXTRACTED: 'Old Spice Tigerclaw Stick 50ml' (ID: 38941) - Price: 899.00
# [16:03:33] EXTRACTED: 'Lady Speed Zero Stick 39.6gm' (ID: 38942) - Price: 660.00
# [16:03:34] EXTRACTED: 'Rexona Men Workout Hi Impact S' (ID: 38943) - Price: 750.00
# [16:03:34] EXTRACTED: 'Rexona Men Cobalt 48h Stick 40' (ID: 38944) - Price: 720.00
# [16:03:34] EXTRACTED: 'Rexona Men Anti Bacterial 48h' (ID: 38945) - Price: 750.00
# [16:03:34] EXTRACTED: 'Rexona Men Invisible Black Whi' (ID: 38946) - Price: 720.00
# [16:03:34] PAGE COMPLETE: Page 61: 20/33 products extracted
# [16:03:34] PAGINATION: Checking for page 62
# [16:03:34] PAGINATION: No next button found
# [16:03:34] DEPARTMENT COMPLETE: No more pages after page 61
# ────────────────────────────────────────────────────────────────────────────────
# DEPARTMENT 007 COMPLETED!
# Total products: 1220
# Time taken: 1071.43 seconds
# ────────────────────────────────────────────────────────────────────────────────
# [16:03:34] PAGE CLOSED: Department 007 browser page closed
# [16:03:35] CSV SAVED: 7280 products saved to rahim_store_products_20251109_141602.csv
#
# ════════════════════════════════════════════════════════════════════════════════
# SCRAPING COMPLETED - FINAL SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
# Total duration: 6452.44 seconds
# Total products: 7280
# Failed extractions: 0
# Output file: rahim_store_products_20251109_141602.csv
#
# DEPARTMENT BREAKDOWN:
#    └── Department 001: 1820 products
#    └── Department 002: 2000 products
#    └── Department 003: 380 products
#    └── Department 004: 860 products
#    └── Department 005: 500 products
#    └── Department 006: 500 products
#    └── Department 007: 1220 products
#
# Success rate: 100.0%
# ════════════════════════════════════════════════════════════════════════════════
# [16:03:35] BROWSER CLOSED: All resources cleaned up

# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.55.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from pyee<14,>=13->playwright) (4.15.0)
# Downloading playwright-1.55.0-py3-none-manylinux1_x86_64.whl (45.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 14.4 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.55.0 pyee-13.0.0
# Downloading Chromium 140.0.7339.16 (playwright build v1187) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1187/chromium-linux.zip
# 173.7 MiB [] 0% 11.5s173.7 MiB [] 0% 3.2s173.7 MiB [] 1% 2.4s173.7 MiB [] 2% 2.2s173.7 MiB [] 3% 2.0s173.7 MiB [] 4% 1.9s173.7 MiB [] 5% 2.1s173.7 MiB [] 6% 2.2s173.7 MiB [] 7% 2.1s173.7 MiB [] 8% 2.0s173.7 MiB [] 9% 2.0s173.7 MiB [] 10% 2.0s173.7 MiB [] 11% 1.9s173.7 MiB [] 12% 1.9s173.7 MiB [] 13% 1.8s173.7 MiB [] 15% 1.7s173.7 MiB [] 16% 1.7s173.7 MiB [] 17% 1.6s173.7 MiB [] 18% 1.6s173.7 MiB [] 20% 1.5s173.7 MiB [] 20% 1.6s173.7 MiB [] 22% 1.6s173.7 MiB [] 23% 1.5s173.7 MiB [] 24% 1.4s173.7 MiB [] 25% 1.4s173.7 MiB [] 27% 1.4s173.7 MiB [] 28% 1.3s173.7 MiB [] 29% 1.3s173.7 MiB [] 30% 1.2s173.7 MiB [] 32% 1.2s173.7 MiB [] 33% 1.2s173.7 MiB [] 34% 1.1s173.7 MiB [] 35% 1.1s173.7 MiB [] 37% 1.1s173.7 MiB [] 38% 1.0s173.7 MiB [] 40% 1.0s173.7 MiB [] 41% 1.0s173.7 MiB [] 42% 0.9s173.7 MiB [] 44% 0.9s173.7 MiB [] 45% 0.9s173.7 MiB [] 47% 0.8s173.7 MiB [] 48% 0.8s173.7 MiB [] 49% 0.8s173.7 MiB [] 51% 0.8s173.7 MiB [] 51% 0.7s173.7 MiB [] 53% 0.7s173.7 MiB [] 54% 0.7s173.7 MiB [] 56% 0.7s173.7 MiB [] 58% 0.6s173.7 MiB [] 59% 0.6s173.7 MiB [] 60% 0.6s173.7 MiB [] 62% 0.6s173.7 MiB [] 63% 0.5s173.7 MiB [] 65% 0.5s173.7 MiB [] 66% 0.5s173.7 MiB [] 67% 0.5s173.7 MiB [] 68% 0.5s173.7 MiB [] 69% 0.5s173.7 MiB [] 70% 0.4s173.7 MiB [] 71% 0.4s173.7 MiB [] 72% 0.4s173.7 MiB [] 73% 0.4s173.7 MiB [] 74% 0.4s173.7 MiB [] 75% 0.4s173.7 MiB [] 76% 0.4s173.7 MiB [] 77% 0.3s173.7 MiB [] 79% 0.3s173.7 MiB [] 80% 0.3s173.7 MiB [] 81% 0.3s173.7 MiB [] 82% 0.3s173.7 MiB [] 84% 0.2s173.7 MiB [] 85% 0.2s173.7 MiB [] 86% 0.2s173.7 MiB [] 88% 0.2s173.7 MiB [] 89% 0.2s173.7 MiB [] 90% 0.1s173.7 MiB [] 91% 0.1s173.7 MiB [] 92% 0.1s173.7 MiB [] 94% 0.1s173.7 MiB [] 95% 0.1s173.7 MiB [] 97% 0.0s173.7 MiB [] 98% 0.0s173.7 MiB [] 99% 0.0s173.7 MiB [] 100% 0.0s
# Chromium 140.0.7339.16 (playwright build v1187) downloaded to /root/.cache/ms-playwright/chromium-1187
# Downloading Chromium Headless Shell 140.0.7339.16 (playwright build v1187) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1187/chromium-headless-shell-linux.zip
# 104.3 MiB [] 0% 0.0s104.3 MiB [] 1% 1.5s104.3 MiB [] 2% 1.6s104.3 MiB [] 3% 1.5s104.3 MiB [] 4% 1.4s104.3 MiB [] 5% 1.3s104.3 MiB [] 6% 1.4s104.3 MiB [] 7% 1.3s104.3 MiB [] 8% 1.4s104.3 MiB [] 9% 1.5s104.3 MiB [] 10% 1.5s104.3 MiB [] 11% 1.4s104.3 MiB [] 13% 1.4s104.3 MiB [] 14% 1.3s104.3 MiB [] 15% 1.3s104.3 MiB [] 16% 1.3s104.3 MiB [] 18% 1.3s104.3 MiB [] 20% 1.2s104.3 MiB [] 21% 1.1s104.3 MiB [] 24% 1.0s104.3 MiB [] 26% 1.0s104.3 MiB [] 28% 0.9s104.3 MiB [] 29% 0.9s104.3 MiB [] 31% 0.9s104.3 MiB [] 33% 0.8s104.3 MiB [] 34% 0.8s104.3 MiB [] 36% 0.8s104.3 MiB [] 38% 0.7s104.3 MiB [] 41% 0.7s104.3 MiB [] 42% 0.7s104.3 MiB [] 44% 0.6s104.3 MiB [] 47% 0.6s104.3 MiB [] 48% 0.6s104.3 MiB [] 50% 0.6s104.3 MiB [] 52% 0.5s104.3 MiB [] 54% 0.5s104.3 MiB [] 56% 0.5s104.3 MiB [] 59% 0.4s104.3 MiB [] 62% 0.4s104.3 MiB [] 65% 0.4s104.3 MiB [] 68% 0.3s104.3 MiB [] 70% 0.3s104.3 MiB [] 72% 0.3s104.3 MiB [] 73% 0.3s104.3 MiB [] 75% 0.2s104.3 MiB [] 77% 0.2s104.3 MiB [] 78% 0.2s104.3 MiB [] 80% 0.2s104.3 MiB [] 82% 0.2s104.3 MiB [] 85% 0.1s104.3 MiB [] 86% 0.1s104.3 MiB [] 89% 0.1s104.3 MiB [] 91% 0.1s104.3 MiB [] 94% 0.1s104.3 MiB [] 96% 0.0s104.3 MiB [] 99% 0.0s104.3 MiB [] 100% 0.0s
# Chromium Headless Shell 140.0.7339.16 (playwright build v1187) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1187
# Downloading Firefox 141.0 (playwright build v1490) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1490/firefox-ubuntu-22.04.zip
# 96 MiB [] 0% 0.0s96 MiB [] 0% 2.1s96 MiB [] 2% 1.3s96 MiB [] 3% 1.2s96 MiB [] 5% 1.1s96 MiB [] 7% 1.0s96 MiB [] 9% 1.0s96 MiB [] 9% 1.1s96 MiB [] 10% 1.1s96 MiB [] 12% 1.1s96 MiB [] 13% 1.0s96 MiB [] 15% 1.0s96 MiB [] 16% 1.0s96 MiB [] 18% 0.9s96 MiB [] 19% 0.9s96 MiB [] 20% 1.0s96 MiB [] 21% 0.9s96 MiB [] 23% 0.9s96 MiB [] 25% 0.9s96 MiB [] 27% 0.8s96 MiB [] 30% 0.8s96 MiB [] 31% 0.7s96 MiB [] 32% 0.7s96 MiB [] 34% 0.7s96 MiB [] 37% 0.7s96 MiB [] 38% 0.7s96 MiB [] 39% 0.7s96 MiB [] 42% 0.6s96 MiB [] 44% 0.6s96 MiB [] 47% 0.5s96 MiB [] 49% 0.5s96 MiB [] 50% 0.5s96 MiB [] 52% 0.5s96 MiB [] 55% 0.4s96 MiB [] 57% 0.4s96 MiB [] 59% 0.4s96 MiB [] 61% 0.4s96 MiB [] 62% 0.4s96 MiB [] 64% 0.3s96 MiB [] 66% 0.3s96 MiB [] 68% 0.3s96 MiB [] 71% 0.3s96 MiB [] 73% 0.2s96 MiB [] 76% 0.2s96 MiB [] 78% 0.2s96 MiB [] 80% 0.2s96 MiB [] 83% 0.2s96 MiB [] 85% 0.1s96 MiB [] 88% 0.1s96 MiB [] 90% 0.1s96 MiB [] 92% 0.1s96 MiB [] 94% 0.1s96 MiB [] 96% 0.0s96 MiB [] 97% 0.0s96 MiB [] 100% 0.0s
# Firefox 141.0 (playwright build v1490) downloaded to /root/.cache/ms-playwright/firefox-1490
# Downloading Webkit 26.0 (playwright build v2203) from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2203/webkit-ubuntu-22.04.zip
# 94.6 MiB [] 0% 0.0s94.6 MiB [] 0% 2.6s94.6 MiB [] 1% 1.6s94.6 MiB [] 3% 1.5s94.6 MiB [] 4% 1.5s94.6 MiB [] 5% 1.4s94.6 MiB [] 6% 1.3s94.6 MiB [] 7% 1.3s94.6 MiB [] 8% 1.3s94.6 MiB [] 9% 1.5s94.6 MiB [] 10% 1.3s94.6 MiB [] 11% 1.4s94.6 MiB [] 12% 1.4s94.6 MiB [] 13% 1.5s94.6 MiB [] 14% 1.5s94.6 MiB [] 14% 1.6s94.6 MiB [] 15% 1.6s94.6 MiB [] 16% 1.7s94.6 MiB [] 17% 1.7s94.6 MiB [] 18% 1.6s94.6 MiB [] 19% 1.6s94.6 MiB [] 19% 1.7s94.6 MiB [] 20% 1.6s94.6 MiB [] 21% 1.6s94.6 MiB [] 22% 1.6s94.6 MiB [] 23% 1.5s94.6 MiB [] 24% 1.5s94.6 MiB [] 25% 1.5s94.6 MiB [] 26% 1.4s94.6 MiB [] 27% 1.4s94.6 MiB [] 28% 1.4s94.6 MiB [] 29% 1.3s94.6 MiB [] 31% 1.3s94.6 MiB [] 32% 1.3s94.6 MiB [] 33% 1.3s94.6 MiB [] 34% 1.3s94.6 MiB [] 35% 1.3s94.6 MiB [] 36% 1.2s94.6 MiB [] 37% 1.2s94.6 MiB [] 38% 1.2s94.6 MiB [] 39% 1.2s94.6 MiB [] 40% 1.2s94.6 MiB [] 41% 1.1s94.6 MiB [] 42% 1.1s94.6 MiB [] 44% 1.0s94.6 MiB [] 45% 1.0s94.6 MiB [] 46% 1.0s94.6 MiB [] 47% 1.0s94.6 MiB [] 49% 0.9s94.6 MiB [] 50% 0.9s94.6 MiB [] 51% 0.9s94.6 MiB [] 52% 0.9s94.6 MiB [] 54% 0.8s94.6 MiB [] 55% 0.8s94.6 MiB [] 56% 0.8s94.6 MiB [] 57% 0.8s94.6 MiB [] 59% 0.7s94.6 MiB [] 60% 0.7s94.6 MiB [] 61% 0.7s94.6 MiB [] 62% 0.7s94.6 MiB [] 63% 0.6s94.6 MiB [] 65% 0.6s94.6 MiB [] 66% 0.6s94.6 MiB [] 67% 0.6s94.6 MiB [] 68% 0.5s94.6 MiB [] 69% 0.5s94.6 MiB [] 70% 0.5s94.6 MiB [] 72% 0.5s94.6 MiB [] 73% 0.5s94.6 MiB [] 74% 0.4s94.6 MiB [] 75% 0.4s94.6 MiB [] 76% 0.4s94.6 MiB [] 77% 0.4s94.6 MiB [] 78% 0.4s94.6 MiB [] 79% 0.3s94.6 MiB [] 80% 0.3s94.6 MiB [] 81% 0.3s94.6 MiB [] 83% 0.3s94.6 MiB [] 84% 0.3s94.6 MiB [] 86% 0.2s94.6 MiB [] 87% 0.2s94.6 MiB [] 89% 0.2s94.6 MiB [] 91% 0.1s94.6 MiB [] 92% 0.1s94.6 MiB [] 94% 0.1s94.6 MiB [] 95% 0.1s94.6 MiB [] 97% 0.0s94.6 MiB [] 100% 0.0s
# Webkit 26.0 (playwright build v2203) downloaded to /root/.cache/ms-playwright/webkit-2203
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 41% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:934:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1056:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1045:7)
#     at async i.<anonymous> (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)
