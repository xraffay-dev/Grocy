# %%
# !pip install playwright tqdm --quiet
# !playwright install chromium
# !playwright install-deps chromium
# Out:
# Installing dependencies...
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,398 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,838 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,135 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,817 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,479 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,288 kB]
# Fetched 28.9 MB in 4s (8,203 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk-bridge2.0-0 set to manually installed.
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libatspi2.0-0 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxcomposite1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.12).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.6).
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# The following additional packages will be installed:
#   xfonts-encodings xfonts-utils xserver-common
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma xfonts-base
# The following NEW packages will be installed:
#   fonts-freefont-ttf fonts-ipafont-gothic fonts-noto-color-emoji
#   fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei xfonts-cyrillic
#   xfonts-encodings xfonts-scalable xfonts-utils
# The following packages will be upgraded:
#   xserver-common xvfb
# 2 upgraded, 10 newly installed, 0 to remove and 40 not upgraded.
# Need to get 29.3 MB of archives.
# After this operation, 67.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.16 [29.5 kB]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.16 [866 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Fetched 29.3 MB in 1s (24.6 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 126455 files and directories currently installed.)
# Preparing to unpack .../00-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../01-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../02-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../03-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-unifont.
# Preparing to unpack .../04-fonts-unifont_1%3a14.0.01-1_all.deb ...
# Unpacking fonts-unifont (1:14.0.01-1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../05-fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../06-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../07-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../08-xfonts-cyrillic_1%3a1.0.5_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.5) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../09-xfonts-scalable_1%3a1.0.3-1.2ubuntu1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Preparing to unpack .../10-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.16_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.16) over (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Preparing to unpack .../11-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.16_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.16) over (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Setting up fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import os
import re
import pandas as pd
import asyncio
from playwright.async_api import async_playwright
import nest_asyncio

# Allow nested event loops (for Colab)
nest_asyncio.apply()

# %%
CATEGORY_GROUPS = {
    "Groceries": [
        "oil-ghee",
        "sauces-price-in-pakistan",
        "local-drinks-price-in-pakistan",
        "milk-price-in-pakistan",
        "butter-price-in-pakistan",
        "egg-price-in-pakistan"
    ],
    "Electronics": [
        "air-purifier-price-in-pakistan",
        "microwave-oven-price-in-pakistan",
        "blender-price-in-pakistan",
        "washing-machine-price-in-pakistan",
        "food-processor-price-in-pakistan"
    ],
    "Perfumes": [
        "men-perfume-price-in-pakistan",
        "best-perfume-for-women",
        "buy-perfume-gift-set",
        "deodorant-price-in-pakistan"
    ],
    "Makeup": [
        "makeup-foundation-price-in-pakistan",
        "lipstick-price-in-pakistan",
        "makeup-palettes-in-pakistan",
        "buy-eyeshadow-online"
    ],
    "Skin Care": [
        "best-bb-and-cc-creams",
        "sheet-mask-price-in-pakistan",
        "face-wash-price-in-pakistan",
        "body-scrub-in-pakistan"
    ],
    "Toys": [
        "toy-car-price-in-pakistan",
        "gaming-console-price-in-pakistan",
        "video-game-price-in-pakistan",
        "activity-toys",
        "baby-push-car-price-in-pakistan"
    ]
}

# %%
async def extract_text(element, selector: str):
    try:
        el = await element.query_selector(selector)
        return (await el.inner_text()).strip() if el else None
    except:
        return None


async def extract_attribute(element, selector: str, attribute: str):
    try:
        el = await element.query_selector(selector)
        return await el.get_attribute(attribute) if el else None
    except:
        return None


def parse_price_text(price_text: str):
    """Extract original and discounted prices."""
    if not price_text:
        return None, None
    prices = re.findall(r"Rs\.([0-9,]+)", price_text)
    if len(prices) == 2:
        return prices[1].replace(",", ""), prices[0].replace(",", "")
    elif len(prices) == 1:
        p = prices[0].replace(",", "")
        return p, p
    return None, None

# %%
async def extract_product_data(card):
    """Extract data from a single product card."""
    try:
        name_elem = await card.query_selector(".product-title a")
        name = (await name_elem.inner_text()).strip() if name_elem else "N/A"
        url_part = await name_elem.get_attribute("href") if name_elem else ""
        full_url = f"https://alfatah.pk{url_part}" if url_part else "N/A"

        price_text = await extract_text(card, ".product-price")
        original_price, discount_price = parse_price_text(price_text)

        discount_elem = await card.query_selector(".product-sale-badge")
        discount_text = (await discount_elem.inner_text()).strip() if discount_elem else "No Discount"

        img_elem = await card.query_selector("img")
        image_url = await img_elem.get_attribute("src") if img_elem else None
        if not image_url:
            srcset = await img_elem.get_attribute("srcset") if img_elem else ""
            if srcset:
                image_url = srcset.split(",")[0].split(" ")[0]
        if image_url and not image_url.startswith("http"):
            image_url = f"https:{image_url}" if image_url.startswith("//") else f"https://alfatah.pk{image_url}"

        return {
            "Name": name,
            "Original Price (Rs)": original_price or "N/A",
            "Discounted Price (Rs)": discount_price or "N/A",
            "Discount": discount_text,
            "Product URL": full_url,
            "Image URL": image_url or "N/A",
        }
    except Exception as e:
        print(f"Error extracting product: {e}")
        return None

# %%
async def scrape_category(page, main_category, subcategory):
    """Scrape one subcategory and save CSV inside its folder."""
    products = []
    url = f"https://alfatah.pk/collections/{subcategory}"
    print(f"\n{'='*80}")
    print(f"Scraping [{main_category}] → {subcategory}")
    print(f"URL: {url}")
    print(f"{'='*80}")

    # Make folder for main category
    os.makedirs(main_category, exist_ok=True)

    try:
        await page.goto(url, timeout=60000)
        await page.wait_for_selector(".product-card", timeout=30000)
        await asyncio.sleep(2)
    except Exception as e:
        print(f"Failed to load {subcategory}: {e}")
        return

    product_cards = await page.query_selector_all(".product-card")
    print(f"Found {len(product_cards)} products in {subcategory}")

    for idx, card in enumerate(product_cards, 1):
        data = await extract_product_data(card)
        if data:
            products.append(data)
            print(f"Extracted {idx}/{len(product_cards)}: {data['Name']}")

    if products:
        df = pd.DataFrame(products)
        csv_path = os.path.join(main_category, f"{subcategory}.csv")
        df.to_csv(csv_path, index=False)
        print(f"Saved {len(df)} products to: {csv_path}")
    else:
        print(f"No products found for {subcategory}")

# %%
async def run_scraper():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        for main_category, subcategories in CATEGORY_GROUPS.items():
            print(f"\n{'#'*100}")
            print(f"Processing MAIN CATEGORY: {main_category}")
            print(f"{'#'*100}")
            for subcat in subcategories:
                await scrape_category(page, main_category, subcat)

        await browser.close()
    print("\nAll categories processed successfully.")

# %%
print("Starting scraper...")
await run_scraper()
# Out:
# Starting scraper...
#
# ####################################################################################################
# Processing MAIN CATEGORY: Groceries
# ####################################################################################################
#
# ================================================================================
# Scraping [Groceries] → oil-ghee
# URL: https://alfatah.pk/collections/oil-ghee
# ================================================================================
# Found 160 products in oil-ghee
# Extracted 1/160: DALDA COOKING OIL POUCH 1 LTR
# Extracted 2/160: MUNDIAL OLIVE OIL POMACE TIN 4 LTR
# Extracted 3/160: SUFI CANOLA COOKING OIL POUCH 1 LTR
# Extracted 4/160: SASSO OLIVE OIL TIN 100 ML
# Extracted 5/160: SEASONS CANOLA OIL POUCH 1 LTR
# Extracted 6/160: FILIPPO BERIO OLIVE OIL EXTRA VIRGIN BOTTLE 250 ML
# Extracted 7/160: CANOLIVE PREMIUM CANOLA OIL POUCH 1 LTR
# Extracted 8/160: SASSO OLIVE OIL TIN 200 ML
# Extracted 9/160: MEZAN OLIVOLA OLIVE AND CANOLA OIL 1 LTR POUCH
# Extracted 10/160: BORGES EXTRA VIRGIN OLIVE OIL BOTTLE 125 ML
# Extracted 11/160: SUFI SUNFLOWER COOKING OIL POUCH 1 LTR
# Extracted 12/160: DALDA CANOLA OIL POUCH 1 LTR
# Extracted 13/160: MUNDIAL OLIVE OIL EXTRA VIRGIN BOTTLE 250 ML
# Extracted 14/160: DALDA COOKING OIL STAND UP POUCH 1 LTR
# Extracted 15/160: BORGES EXTRA VIRGIN OLIVE OIL BOTTLE 250 ML
# Extracted 16/160: MUNDIAL OLIVE OIL POMACE BOTTLE 250 ML
# Extracted 17/160: FF GLAZE COOKING OIL POUCH 1 LTR
# Extracted 18/160: DALDA OLIVE OIL POMACE BOTTLE 500 ML
# Extracted 19/160: MEZAN COOKING OIL POUCH 1 LTR
# Extracted 20/160: MUNDIAL OLIVE OIL POMACE BOTTLE 1 LTR
# Extracted 21/160: MUNDIAL OLIVE OIL EXTRA VIRGIN BOTTLE 1 LTR
# Extracted 22/160: KAUSAR COOKING OIL POUCH 1 LTR
# Extracted 23/160: FILIPPO BERIO OLIVE OIL BOTTLE 500 ML
# Extracted 24/160: MANPASAND COOKING OIL POUCH 900 ML
# Extracted 25/160: MUNDIAL OLIVE OIL POMACE TIN 3 LTR
# Extracted 26/160: DALDA SUNFLOWER OIL POUCH 1 LTR
# Extracted 27/160: FILIPPO BERIO ORGANIC EXTRA VIRGIN OLIVE OIL 500 ML
# Extracted 28/160: BORGES EXTRA VIRGIN OLIVE OIL BOTTLE 500 ML
# Extracted 29/160: DALDA OLIVE OIL EXTRA VIRGIN 1 LTR
# Extracted 30/160: SEASONS CANOLA OIL BOTTLE 3 LTR
# Extracted 31/160: KAUSAR CANOLA OIL POUCH 1 LTR
# Extracted 32/160: MUNDIAL OLIVE OIL EXTRA VIRGIN BOTTLE 500 ML
# Extracted 33/160: SEASONS CANOLA OIL BOTTLE 4.5 LTR
# Extracted 34/160: FILIPPO BERIO OLIVE OIL EXTRA VIRGIN BOTTLE 500 ML
# Extracted 35/160: SUFI CANOLA COOKING OIL BOTTLE 4.5 LTR BASIC
# Extracted 36/160: DALDA OLIVE OIL POMACE 1 LTR
# Extracted 37/160: DALDA COOKING OIL BOTTLE 3 LTR
# Extracted 38/160: FILIPPO BERIO OLIVE OIL FOR SAUCES PASTA BOTTLE 1 LTR
# Extracted 39/160: DALDA COOKING OIL BOTTLE 4.5 LTR
# Extracted 40/160: DALDA OLIVE OIL EXTRA VIRGIN BOTTLE 500 ML
# Extracted 41/160: SUFI CANOLA COOKING OIL BOTTLE 3 LTR
# Extracted 42/160: MUNDIAL OLIVE OIL POMACE TIN 1 LTR
# Extracted 43/160: KALLAR KAHAR OLIVE PRESS EXTRA VIRGIN OLIVE OIL 500ML
# Extracted 44/160: SEASONS COOKING OIL POUCH 1 LTR PC
# Extracted 45/160: FILIPPO BERIO OLIVE OIL EXTRA VIRGIN BOTTLE 1 LTR
# Extracted 46/160: MEZAN CANOLA OIL POUCH 1 LTR
# Extracted 47/160: CAVALLO POMACE OLIVE OIL TIN 2 LTR
# Extracted 48/160: FF GLAZE CANOLA OIL POUCH 1 LTR
# Extracted 49/160: BORGES EXTRA LIGHT OLIVE OIL BOTTLE 250 ML
# Extracted 50/160: SUFI SUNFLOWER COOKING OIL BOTTLE 4.5 LTR BASIC
# Extracted 51/160: MUNDIAL OLIVE OIL POMACE TIN 400 ML
# Extracted 52/160: FF GLAZE SUNFLOWER OIL POUCH 1 LTR
# Extracted 53/160: MUNDIAL OLIVE OIL EXTRA VIRGIN TIN 3 LTR
# Extracted 54/160: SUFI SUNFLOWER COOKING OIL BOTTLE 3 LTR
# Extracted 55/160: BORGES EXTRA LIGHT OLIVE OIL BOTTLE 500 ML
# Extracted 56/160: FF GLAZE MUSTARD COOKING OIL BOTTLE 3LTR
# Extracted 57/160: BORGES EXTRA LIGHT OIL BOTTLE 125 ML
# Extracted 58/160: SUFI SOYABEAN COOKING OIL POUCH 1 LTR
# Extracted 59/160: KALLAR KAHAR OLIVE PRESS EXTRA VIRGIN OLIVE OIL 250ML
# Extracted 60/160: RAFHAN CORN OIL BOTTLE 3 LTR
# Extracted 61/160: BORGES EXTRA VIRGIN OLIVE OIL ORIGINAL BOTTLE 1 LTR
# Extracted 62/160: SUFI CANOLA COOKING OIL BOTTLE 1.8 LTR
# Extracted 63/160: MUNDIAL POMACE OIL TIN 175 ML
# Extracted 64/160: SUFI CANOLA COOKING OIL BOTTLE 750 ML
# Extracted 65/160: MUNDIAL OLIVE OIL EXTRA VIRGIN BOTTLE 750 ML
# Extracted 66/160: RAFHAN CORN OIL BOTTLE SAVE RS.75 1 LTR
# Extracted 67/160: BORGES EXTRA VIRGEN OLIVE OIL BOTTLE 750 ML
# Extracted 68/160: MUNDIAL OLIVE OIL POMACE BOTTLE 500 ML
# Extracted 69/160: DEW DROP OLIVE POMACE OIL SMOOTH & LIGHT 250 ML
# Extracted 70/160: SEASONS CANOLA OIL GALON 10 LTR
# Extracted 71/160: MUNDIAL POMACE OIL TIN 125 ML
# Extracted 72/160: SUFI POMACE OLIVE OIL BOTTLE 500ML
# Extracted 73/160: RAFHAN CORN OIL TIN 5 LTR
# Extracted 74/160: BORGES EXTRA LIGHT OLIVE OIL BOTTLE 1 LTR
# Extracted 75/160: BORGES OLIVE OIL POMACE BOTTLE 1 LTR BASIC
# Extracted 76/160: SUFI CANOLA COOKING OIL GALON 10 LTR
# Extracted 77/160: DEW DROP OLIVE OIL EXTRA VIRGIN TRADITIONAL 250 ML
# Extracted 78/160: SEASONS CORN OIL BOTTLE 4.5 LTR
# Extracted 79/160: CAVALLO POMACE OLIVE OIL TIN 5 LTR
# Extracted 80/160: SASSO OLIVE OIL EXTRA VIRGIN BOTTLE 250 ML
# Extracted 81/160: FF GLAZE CORN OIL BOTTLE 3 LTR
# Extracted 82/160: DALDA OLIVE OIL EXTRA VIRGIN 4 LTR
# Extracted 83/160: FILIPPO BERIO OLIVE OIL EXTRA LIGHT TASTING 3 LTR
# Extracted 84/160: DAALI SARSON COOKING OIL 1 LTR
# Extracted 85/160: SASSO OLIVE OIL TIN 400 ML
# Extracted 86/160: RAFHAN CORN OIL TIN 3 LTR BASIC
# Extracted 87/160: MUNDIAL OLIVE OIL EXTRA VIRGIN TIN 1 LTR
# Extracted 88/160: MUNDIAL OLIVE OIL EXTRA LIGHT BOTTLE 1 LTR
# Extracted 89/160: DALDA OLIVE OIL POMACE TIN 4 LTR
# Extracted 90/160: CAVALLO POMACE OLIVE OIL TIN 4 LTR
# Extracted 91/160: SASSO OLIVE OIL TIN 1 LTR
# Extracted 92/160: CAVALLO POMACE OLIVE OIL TIN 3 LTR
# Extracted 93/160: FF GLAZE SOYBEAN COOKING OIL POUCH 1LTR
# Extracted 94/160: DALDA OLIVE OIL POMACE TIN 3 LTR
# Extracted 95/160: BORGES OLIVE POMACE OIL TIN 4LTR
# Extracted 96/160: BORGES EXTRA LIGHT OLIVE OIL BOTTLE 2 LTR
# Extracted 97/160: COROLI SUNFLOWER OIL BOTTLE 3 LTR
# Extracted 98/160: DALDA OLIVE OIL EXTRA VIRGIN TIN 3 LTR
# Extracted 99/160: BORGES EXTRA VIRGIN OLIVE OIL BOTTLE 2 LTR
# Extracted 100/160: COROLI SUNFLOWER OIL BOTTLE 1.8 LTR
# Extracted 101/160: BORGES OLIVE POMACE OIL TIN 100 ML
# Extracted 102/160: COROLI CORN OIL BOTTLE 1.8 LTR
# Extracted 103/160: SUFI EXTRA VIRGIN OLIVE OIL BOTTLE 500ML
# Extracted 104/160: SUFI SUNFLOWER COOKING OIL GALON 10 LTR
# Extracted 105/160: BORGES EXTRA LIGHT OLIVE OIL BOTTLE 5 LTR
# Extracted 106/160: MUNDIAL OLIVE OIL EXTRA LIGHT TIN 3 LTR
# Extracted 107/160: SUFI SOYABEAN COOKING OIL BOTTLE 1.8 LTR
# Extracted 108/160: DEW DROP OLIVE OIL EXTRA VIRGIN TRADITIONAL 500 ML
# Extracted 109/160: SEASONS CORN OIL GALON 10 LTR
# Extracted 110/160: FILIPPO BERIO OLIVE OIL MILD AND LIGHT IN COLOUR 5 LTR
# Extracted 111/160: SUFI SOYABEAN COOKING OIL BOTTLE 4.5 LTR BASIC
# Extracted 112/160: SASSO OLIVE OIL EXTRA VIRGIN BOTTLE 500 ML
# Extracted 113/160: BORGES EXTRA VIRGIN OLIVE OIL ORIGINAL TIN 4 LTR
# Extracted 114/160: EVA COOKING OIL BOTTLE 3 LTR
# Extracted 115/160: BORGES OLIVE OIL POMACE BOTTLE 2 LTR BASIC
# Extracted 116/160: EVA COOKING OIL BOTTLE 5 LTR
# Extracted 117/160: SASSO OLIVE OIL BOTTLE 500 ML
# Extracted 118/160: SUFI SOYABEAN COOKING OIL BOTTLE 3 LTR
# Extracted 119/160: BORGES EXTRA LIGHT OLIVE OIL TIN BOTTLE 4 LTR
# Extracted 120/160: COROLI CORN OIL BOTTLE 3 LTR
# Extracted 121/160: BORGES EXTRA VIRGIN OLIVE OIL ORIGINAL 5 LTR
# Extracted 122/160: RAFHAN CORN OIL CAN 16 LTR
# Extracted 123/160: SASSO OLIVE OIL EXTRA VIRGIN BOTTLE 1 LTR
# Extracted 124/160: COROLI CORN OIL BOTTLE 4 LTR
# Extracted 125/160: COROLI CANOLA OIL BOTTLE 1.8 LTR
# Extracted 126/160: SASSO OLIVE OIL BOTTLE 1 LTR
# Extracted 127/160: BORGES OLIVE OIL POMACE BOTTLE 5 LTR BASIC
# Extracted 128/160: FF GLAZE SUNFLOWER OIL BOTTLE 3 LTR
# Extracted 129/160: NATURES OWN POMACE OLIVE OIL CHOLESTROL FREE 4 LTR
# Extracted 130/160: FF GLAZE CANOLA OIL BOTTLE 3 LTR
# Extracted 131/160: DEW DROP OLIVE POMACE OIL SMOOTH & LIGHT 500 ML
# Extracted 132/160: EVA CANOLA OIL BOTTLE 5 LTR
# Extracted 133/160: DEW DROP OLIVE POMACE OIL SMOOTH & LIGHT 4 LITTER
# Extracted 134/160: SUFI EXTRA VIRGIN OLIVE OIL BOTTLE 1LTR
# Extracted 135/160: RAFHAN CORN OIL TIN 10 LTR BASIC
# Extracted 136/160: SEASONS COOKING OIL GALON 16 LTR
# Extracted 137/160: SUFI POMACE OLIVE OIL TIN 3 LTR
# Extracted 138/160: EVA PURE CANOLA OIL BOTTLE 3 LTR
# Extracted 139/160: DEW DROP OLIVE OIL EXTRA VIRGIN TRADITIONAL 1000 ML
# Extracted 140/160: DEW DROP OLIVE POMACE OIL SMOOTH & LIGHT 1 LTR
# Extracted 141/160: SASSO OLIVE OIL TIN 3 LTR
# Extracted 142/160: SEASONS COOKING OIL BOTTLE 5 LTR PC
# Extracted 143/160: SEASONS COOKING OIL BOTTLE 3 L LTR
# Extracted 144/160: DALDA VTF BANASPATI GHEE POUCH 1 KG
# Extracted 145/160: SUFI BANASPATI GHEE POUCH 1 KG
# Extracted 146/160: MEZAN BANASPATI GHEE POUCH 1 KG
# Extracted 147/160: MANPASAND BANASPATI GHEE POUCH 900 GM
# Extracted 148/160: KASHMIR BANASPATI GHEE POUCH 1 KG
# Extracted 149/160: KAUSAR BANASPATI POUCH 1 KG
# Extracted 150/160: OLPERS TARKA ASLI DESI GHEE 1 KG
# Extracted 151/160: SUFI BANASPATI GHEE TIN 2.5 KG
# Extracted 152/160: DAALI DESI GHEE 850GM
# Extracted 153/160: PAK DESI GHEE POUCH 250 GM
# Extracted 154/160: PAK DESI GHEE POUCH 500 GM
# Extracted 155/160: DAALI DESI GHEE 450 GM
# Extracted 156/160: PAK DESI GHEE POUCH 1 KG
# Extracted 157/160: SUFI BANASPATI GHEE TIN 5 KG
# Extracted 158/160: PREMA DESI GHEE 800GM
# Extracted 159/160: CANOLIVE BANASPATI GHEE 2.5 KG
# Extracted 160/160: GLAZE COOKING OIL 3 LTR
# Saved 160 products to: Groceries/oil-ghee.csv
#
# ================================================================================
# Scraping [Groceries] → sauces-price-in-pakistan
# Extracted 202/225: NATIONAL PORTUGUESE PERI PERI SAUCE 280 GM
# Extracted 203/225: OREAL CHICKEN POWDER 1 KG
# Extracted 204/225: SHANGRILA PERI PERI HOT SAUCE 285 ML
# Extracted 205/225: SUREE PREMIUM SOY SAUCE 295 ML
# Extracted 206/225: SUREE PASTE TOM YUM 227 GM
# Extracted 207/225: NATIONAL CHILLI GARLIC SAUCE 3.25 KG
# Extracted 208/225: DASHI FLAVORED CHICKEN ZAIQA POWDER 1KG
# Extracted 209/225: FALAK CHICKEN CORN SOUP 50GM
# Extracted 210/225: DIPITT TOMATO KETCHUP 3.9 KG
# Extracted 211/225: SHANGRILA PERI PERI MILD SAUCE 300 ML
# Extracted 212/225: AMERICAN GARDEN SAUCE WORCESTERSHIRE 295 ML
# Extracted 213/225: AMERICAN GARDEN HOT SAUCE LOUISIANA STYLE 473 ML
# Extracted 214/225: MITCHELLS BBQ SAUCE BOTTLE 300 GM
# Extracted 215/225: SUREE SAUCE SWEET 295 ML
# Extracted 216/225: DIPITT BBQ MAYO DIP 300 SAUCE GM
# Extracted 217/225: EL SABOR SAUCE CHEESE DIP 300 GM
# Extracted 218/225: LOBO THAI BASIL SEASONING PASTE 50G
# Extracted 219/225: RAGU SAUCE MARINARA OLD WORLD STYLE 396 GM
# Extracted 220/225: KNORR CRISPY COATING MIX 1 KG
# Extracted 221/225: EL SABOR SAUCE SALSA DIP 315 GM
# Extracted 222/225: RAGU SAUCE CHUNKY TOMATO GARLIC AND ONION 396 GM
# Extracted 223/225: MAMA SITAS OYSTER SAUCE 4.2 KG BASIC
# Extracted 224/225: DIPITT CHILLI GARLIC SAUCE 3.9 KG
# Extracted 225/225: SALMAN VANILLA TOPPING 623 GM
# Saved 225 products to: Groceries/sauces-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Groceries] → local-drinks-price-in-pakistan
# URL: https://alfatah.pk/collections/local-drinks-price-in-pakistan
# ================================================================================
# Found 232 products in local-drinks-price-in-pakistan
# Extracted 1/232: MURREE BREWERY DRINK LEMON MALT CAN 250 ML
# Extracted 2/232: GATORADE DRINK TROPICAL FRUIT BOTTLE 500 ML
# Extracted 3/232: TASTE OF NATURE FRUTI MANGO JUICE GLASS BOTTLE 1LTR- CARTON
# Extracted 4/232: DAYFRESH FLAVOURED MILK BELGIAN CHOCOLATE 225ML-CARTON
# Extracted 5/232: DAYFRESH FLAVOURED MILK BELGIAN CHOCOLATE 225ML
# Extracted 6/232: DAY FRESH FLAVORED MILK NUTTELICIOUS HAZELNUT LOW SUGAR 225ML-CARTON
# Extracted 7/232: DAYFRESH FLAVOURED MILK NUTELICIOUS HAZELNUT 225ML
# Extracted 8/232: MURREE BREWERY MALT 79 TIN 250 ML
# Extracted 9/232: MURREE BREWERY CARBONATED MALT DRINK CINDY TIN 250 ML
# Extracted 10/232: COCA COLA LOCAL TIN 250 ML
# Extracted 11/232: COCA COLA LOCAL CAN 250 ML-CARTON
# Extracted 12/232: COKE ZERO SLIM TIN 250 ML
# Extracted 13/232: COKE ZERO SLIM CAN 250 ML-CARTON
# Extracted 14/232: COCA COLA CSD PET 350ML PC
# Extracted 15/232: COCA COLA DRINK 350ML CARBONATED DRINK-CARTON
# Extracted 16/232: PEPSI BOTTLE 345 ML-CARTON
# Extracted 17/232: PEPSI BOTTLE 345 ML
# Extracted 18/232: 7UP BOTTLE 345 ML
# Extracted 19/232: 7 UP BOTTLE 345 ML-CARTON
# Extracted 20/232: SPRITE LOCAL CAN 250 ML-CARTON
# Extracted 21/232: SPRITE LOCAL TIN 250 ML
# Extracted 22/232: COCA COLA BOTTLE 1.5 LTR
# Extracted 23/232: COKE BOTTLE 1.5 LTR-CARTON
# Extracted 24/232: SHEZAN JUICE MANGO 250 ML
# Extracted 25/232: SHEZAN JUICE MANGO 250 ML-CARTON
# Extracted 26/232: NESTLE JUICE FRUITA VITALS CHAUNSA NECTAR 200 ML-CARTON
# Extracted 27/232: NESTLE JUICE FRUITA VITALS CHAUNSA NECTAR 200 ML
# Extracted 28/232: 7 UP BOTTLE 1.5 LTR-CARTON
# Extracted 29/232: 7UP BOTTLE 1.5 LTR
# Extracted 30/232: COLA NEXT 300 ML
# Extracted 31/232: NESTLE MILO PROTO MALT ENERGY FOOD DRINK 180 ML-CARTON
# Extracted 32/232: NESTLE MILO PROTO MALT ENERGY FOOD DRINK 180 ML
# Extracted 33/232: MOUNTAIN DEW BOTTLE 1.5 LTR-CARTON
# Extracted 34/232: MOUNTAIN DEW BOTTLE 1.5 LTR
# Extracted 35/232: COKE BOTTLE 500 ML-CARTON
# Extracted 36/232: COKE BOTTLE 500 ML
# Extracted 37/232: PEPSI BOTTLE 1.5 LTR
# Extracted 38/232: PEPSI BOTTLE 1.5 LTR-CARTON
# Extracted 39/232: COKE ZERO BOTTLE 500 ML-CARTON
# Extracted 40/232: COKE ZERO BOTTLE 500 ML
# Extracted 41/232: SPRITE 350 ML PET
# Extracted 42/232: SPRITE BOTTLE 500 ML-CARTON
# Extracted 43/232: SPRITE BOTTLE 500 ML
# Extracted 44/232: SLICE MANGO JUICE 200 ML-CARTON
# Extracted 45/232: SLICE MANGO JUICE 200 ML
# Extracted 46/232: SPRITE BOTTLE 1.5 LTR-CARTON
# Extracted 47/232: SPRITE BOTTLE 1.5 LTR
# Extracted 48/232: 7UP FREE BOTTLE 345 ML-CARTON
# Extracted 49/232: 7 UP FREE BOTTLE 345 ML
# Extracted 50/232: SHEZAN MANGO NR BOTTLE JUICE 250 ML-CARTON
# Extracted 51/232: SHEZAN MANGO NR BOTTLE JUICE 225 ML
# Extracted 52/232: COLA NEXT 1000 ML
# Extracted 53/232: NESTLE NESFRUTA JUICE MANGO FRUIT 200 ML-CARTON
# Extracted 54/232: NESTLE NESFRUTA JUICE MANGO FRUIT 200 ML
# Extracted 55/232: MIRINDA BOTTLE 1.5 LTR-CARTON
# Extracted 56/232: MIRINDA BOTTLE 1.5 LTR
# Extracted 57/232: SPRITE ZERO LOCAL TIN 250 ML
# Extracted 58/232: SPRITE ZERO LOCAL CAN 250 ML-CARTON
# Extracted 59/232: PEPSI CAN SLIM LOCAL 250ML-CARTON
# Extracted 60/232: PEPSI TIN SLIM LOCAL 250ML
# Extracted 61/232: 7UP LEMON SLIM CAN 250ML-CARTON
# Extracted 62/232: 7 UP LEMON SLIM TIN 250ML
# Extracted 63/232: SPRITE LEMON MINT 350 ML PET
# Extracted 64/232: STING BERRY BLAST 500 ML-CARTON
# Extracted 65/232: STING BERRY BLAST 500 ML
# Extracted 66/232: NESTLE JUICE FRUITA VITALS ROYAL MANGOES 200 ML-CARTON
# Extracted 67/232: NESTLE JUICE FRUITA VITALS ROYAL MANGOES 200 ML
# Extracted 68/232: COCA COLA ZERO SUGAR 350 ML PET
# Extracted 69/232: 7 UP ZERO SUGAR LOCAL TIN 250 ML
# Extracted 70/232: 7 UP FREE LOCAL CAN 250 ML-CARTON
# Extracted 71/232: FOREST CLUB SODA DRINK TIN 250 ML
# Extracted 72/232: FANTA ORANGE LOCAL CAN 250 ML-CARTON
# Extracted 73/232: FANTA ORANGE LOCAL TIN 250 ML
# Extracted 74/232: PEPSI ZERO CAN 250 ML
# Extracted 75/232: SPRITE LEMON MINT FLAVOR BOTTLE 500 ML-CARTON
# Extracted 76/232: SPRITE LEMON MINT FLAVOR BOTTLE 500 ML
# Extracted 77/232: PEPSI BOTTLE 500 ML-CARTON
# Extracted 78/232: PEPSI BOTTLE 500 ML
# Extracted 79/232: 7UP BOTTLE 500 ML-CARTON
# Extracted 80/232: 7UP BOTTLE 500 ML
# Extracted 81/232: MIRINDA BOTTLE 345 ML
# Extracted 82/232: MIRINDA BOTTLE 345 ML-CARTON
# Extracted 83/232: SHEZAN JUICE FRUIT PUNCH 250 ML-CARTON
# Extracted 84/232: SHEZAN JUICE FRUIT PUNCH 250 ML
# Extracted 85/232: 7UP BOTTLE FREE 500 ML
# Extracted 86/232: 7 UP BOTTLE FREE 500 ML-CARTON
# Extracted 87/232: SPRITE ZERO 500 ML
# Extracted 88/232: CAPPY PULPY ORANGE FRUIT DRINK 350 ML-CARTON
# Extracted 89/232: CAPPY PULPY ORANGE FRUIT DRINK 350 ML
# Extracted 90/232: PEPSI CSD ZERO 345 ML
# Extracted 91/232: MOUNTAIN DEW BOTTLE 345 ML-CARTON
# Extracted 92/232: MOUNTAIN DEW BOTTLE 345 ML
# Extracted 93/232: 7 UP MINT LEMONADE BOTTLE 345ML
# Extracted 94/232: NESTLE JUICE FRUITA VITALS APPLE NECTAR 200 ML-CARTON
# Extracted 95/232: NESTLE JUICE FRUITA VITALS APPLE NECTAR 200 ML
# Extracted 96/232: GATORADE DRINK BLUE BOLT BOTTLE 500 ML-CARTON
# Extracted 97/232: GATORADE DRINK BLUE BOLT BOTTLE 500 ML
# Extracted 98/232: MURREE BREWERY LEMON MALT BOTTLE 250 ML
# Extracted 99/232: NESTLE JUICE FRUITA VITALS CHAUNSA NECTAR BOTTLE 1 LTR
# Extracted 100/232: SHEZAN LYCHEE NR BOTTLE JUICE 250ML
# Extracted 101/232: PAKOLA ICE CREAM SODA CAN 250 ML-CARTON
# Extracted 102/232: PAKOLA ICE CREAM SODA TIN 250 ML
# Extracted 103/232: MURREE BREWERY PEACH MALT BOTTLE 250 ML
# Extracted 104/232: SPRITE LEMON MINT 1.5 LTR-CARTON
# Extracted 105/232: SPRITE LEMON MINT 1.5L PET
# Extracted 106/232: FANTA ORANGE BOTTLE 500 ML-CARTON
# Extracted 107/232: FANTA ORANGE BOTTLE 500 ML
# Extracted 108/232: NESTLE MILO BOTTLE ENERGY DRINK 220ML
# Extracted 109/232: GATORADE DRINK LEMON LIGHT BOTTLE 500 ML
# Extracted 110/232: SHEZAN JUICE APPLE 250 ML-CARTON
# Extracted 111/232: SHEZAN JUICE APPLE 250 ML
# Extracted 112/232: NESTLE JUICE FRUITA VITALS KINNOW NECTAR 200 ML-CARTON
# Extracted 113/232: NESTLE JUICE FRUITA VITALS KINNOW NECTAR 200 ML
# Extracted 114/232: 7UP BOTTLE LEMON MINT FLAVOUR 500 ML
# Extracted 115/232: MIRINDA SLIM CAN 250 ML-CARTON
# Extracted 116/232: MIRINDA SLIM TIN 250 ML
# Extracted 117/232: NESTLE JUICE FRUITA VITALS PEACH NECTAR 200 ML-CARTON
# Extracted 118/232: NESTLE JUICE FRUITA VITALS PEACH NECTAR 200 ML
# Extracted 119/232: NESTLE NESFRUTA JUICE APPLE FRUIT 200 ML-CARTON
# Extracted 120/232: NESTLE NESFRUTA JUICE APPLE FRUIT 200 ML
# Extracted 121/232: SHEZAN LEMON BARLEY NR BOTTLE JUICE 250 ML
# Extracted 122/232: MURREE BREWERY PEACH MALT CAN 250 ML
# Extracted 123/232: MURREE BREWERY BIG APPLE DRINK 500ML-CARTON
# Extracted 124/232: MURREE BREWERY BIGG APPLE DRINK 500 ML
# Extracted 125/232: NESTLE JUICE FRUITA VITALS RED GRAPES GOLD RANGE 200 ML-CARTON
# Extracted 126/232: NESTLE JUICE FRUITA VITALS RED GRAPES 200 ML
# Extracted 127/232: FANTA ORANGE BOTTLE 1.5 LTR
# Extracted 128/232: FANTA ORANGE BOTTLE 1.5 LTR-CARTON
# Extracted 129/232: MIRINDA BOTTLE 500 ML-CARTON
# Extracted 130/232: MIRINDA BOTTLE 500 ML
# Extracted 131/232: NESTLE FRUITA VITALS SPARKLING FRUIT DRINK PEACH CAN 250ML
# Extracted 132/232: COKE ZERO BOTTLE 1.5 LTR-CARTON
# Extracted 133/232: COKE ZERO BOTTLE 1.5 LTR
# Extracted 134/232: NESCAFE CHILLED LATTE BOTTLE 220ML
# Extracted 135/232: MURREE BREWERY APPLE MALT BOTTLE 250 ML
# Extracted 136/232: NESTLE FRUITA VITALS SPARKLING FRUIT DRINK APPLE CAN 250ML
# Extracted 137/232: NESCAFE CHILLED MOCHA BOTTLE 220ML
# Extracted 138/232: MURREE BREWERY BIGG LYCHEE BOTTLE 500 ML
# Extracted 139/232: MURREE BREWERY PINEAPPLE MALT BOTTLE 250 ML
# Extracted 140/232: MOUNTAIN DEW SLIM CAN 250 ML-CARTON
# Extracted 141/232: MOUNTAIN DEW SLIM TIN 250 ML
# Extracted 142/232: MOUNTAIN DEW BOTTLE 500 ML-CARTON
# Extracted 143/232: MOUNTAIN DEW BOTTLE 500 ML
# Extracted 144/232: STING GOLD RUSH 500 ML-CARTON
# Extracted 145/232: STING GOLD RUSH 500 ML
# Extracted 146/232: MURREE BREWERY LYCHEE DRINK BOTTLE 250 ML
# Extracted 147/232: 7 UP FREE 1.5 LTR-CARTON
# Extracted 148/232: 7 UP ZREO SUGAR 1.5 LTR
# Extracted 149/232: NESTLE JUICE FRUITA VITALS GUAVA NECTAR 200 ML-CARTON
# Extracted 150/232: NESTLE JUICE FRUITA VITALS GUAVA NECTAR 200 ML
# Extracted 151/232: SLICE JUICE MANGO 1LTR- CARTON
# Extracted 152/232: SLICE JUICE MANGO 1LTR
# Extracted 153/232: NESTLE JUICE FRUITA VITALS PINEAPPLE FROM INDONESIA 1 LTR
# Extracted 154/232: NESTLE JUICE FRUITA VITALS ROYAL MANGOES 1LTR-CARTON
# Extracted 155/232: NESTLE JUICE FRUITA VITALS ROYAL MANGOES 1LTR
# Extracted 156/232: NESTLE FRUITA VITAL SPARKLING POMEGRANATE JUICE 240 ML
# Extracted 157/232: MURREE-BREWERY BIGG APPLE 1500ML-CARTON
# Extracted 158/232: MURREE BREWERY BIGG APPLE 1.5 LTR
# Extracted 159/232: COKE JUMBO 2.25LTR-CARTON
# Extracted 160/232: COKE JUMBO 2.25LTR
# Extracted 161/232: MURREE BREWERY MALT 79 BOTTLE 250 ML
# Extracted 162/232: FRUITIEN JUICE JOY MANGO FRUIT DRINK 200 ML
# Extracted 163/232: NESTLE JUICE FRUITA VITALS APPLE NECTAR BOTTLE 1 LTR
# Extracted 164/232: NESCAFE WHITE CHOCOLATE MOCHA DRINK 220ML
# Extracted 165/232: FRESHER JUICE MANGO NECTAR 250ML
# Extracted 166/232: FRESHER JUICE MANGO 500 ML
# Extracted 167/232: NESCAFE CHILLED HAZELNUT 220ML
# Extracted 168/232: NESCAFE SALTED CARAMEL 220 ML
# Extracted 169/232: FRUITIEN JUICE MANGO CHAUNSA NECTAR 200 ML
# Extracted 170/232: MURREE BREWERY LYCHEE MALT BOTTLE 250 ML
# Extracted 171/232: NESTLE JUICE FRUITA VITALS PEACH NECTAR BOTTLE 1 LTR
# Extracted 172/232: MURREE BREWERY DRINK BIGG LYCHEE TIN 250 ML
# Extracted 173/232: PEPSI JUMBO 2.25 LTR-CARTON
# Extracted 174/232: PEPSI JUMBO 2.25LTR
# Extracted 175/232: 7 UP JUMBO 2.25LTR-CARTON
# Extracted 176/232: 7 UP JUMBO 2.25LTR
# Extracted 177/232: PAKOLA LYCHEE FLAVOURED TIN 250 ML
# Extracted 178/232: HALEEB CHAUNSA FRUIT JUICE 200ML
# Extracted 179/232: SHEZAN ALL PURE JUICE MANGO 1 LTR
# Extracted 180/232: MURREE BREWERYS STRAWBERRY MALT BOTTLE 250 ML
# Extracted 181/232: SPRITE ZERO PET BOTTLE 1.5 LTR
# Extracted 182/232: MURREE BREWERY BIGG APPLE CAN 250 ML
# Extracted 183/232: NESTLE JUICE FRUITA VITALS 100% ORANGE PREMIUM 1 LTR
# Extracted 184/232: SHEZAN MANGO JUICE NATURAL SUN RIPENED 200 ML
# Extracted 185/232: MURREE BREWERYS CINDY MALT 250 ML
# Extracted 186/232: MURREE BREWERYS POME MALT BOTTLE 250 ML
# Extracted 187/232: SHEZAN ALL PURE JUICE MANGO 200 ML
# Extracted 188/232: FRESHER JUICE MANGO 1000 ML
# Extracted 189/232: NESTLE JUICE FRUITA VITALS KINNOW NECTAR BOTTLE 1 LTR
# Extracted 190/232: SHEZAN FRUIT PUNCH NR BOTTLE JUICE 250 ML
# Extracted 191/232: FRESHER TETRA JUICE MANGO 200ML
# Extracted 192/232: FRUITIEN JUICE ORANGE 200 ML
# Extracted 193/232: PAKOLA ICE CREAM SODA BOTTLE 1.5 LTR
# Extracted 194/232: SHEZAN FRUIT PUNCH 200 ML 200 ML
# Extracted 195/232: FRUITIEN JUICE PINEAPPLE NECTAR 200 ML
# Extracted 196/232: NESTLE JUICE FRUITA VITALS RED GRAPES FROM SPAIN BOTTLE 1LTR
# Extracted 197/232: FROOT FULL MANGO NECTAR CAN 250ML
# Extracted 198/232: NESTLE NESFRUITA MANGO 1000ML
# Extracted 199/232: MOUNTAIN DEW JUMBO 2.25 LTR
# Extracted 200/232: COCA COLA BOTTLE 1 LTR
# Extracted 201/232: FRESHER JUICE MANGO SUGAR FREE 500ML
# Extracted 202/232: HALEEB TROPICO CHAUNSA FRUIT DRINK 1 LTR
# Extracted 203/232: MURREE-BREWERY LYCHEE 1500ML-CARTON
# Extracted 204/232: MURREE BREWERY BIGG LYCHEE 1.5 LTR
# Extracted 205/232: FRUITIEN JUICE JOY MANGO FRUIT DRINK 1LTR
# Extracted 206/232: NESTLE JUICE FRUITA VITALS GUAVA NECTAR BOTTLE 1 LTR-CARTON
# Extracted 207/232: NESTLE JUICE FRUITA VITALS GUAVA NECTAR BOTTLE 1 LTR
# Extracted 208/232: FRUITIEN JUICE APPLE NECTAR 200 ML
# Extracted 209/232: FRUITIEN JUICE PEACH FRUIT DRINK 200ML
# Extracted 210/232: NESTLE FRUITA VITALS JUICE RED ANAAR GOLD RANGE 1 LTR
# Extracted 211/232: FRUIT FARM MANGO JUICE 500ML
# Extracted 212/232: FRUITIEN JUICE CHAUNSA MANGO NECTAR 1 LTR
# Extracted 213/232: FRUITIEN JUICE APPLE FRUIT DRINK 200ML
# Extracted 214/232: SHEZAN POMEGRANATE NR BOTTLE JUICE 250 ML- CARTON
# Extracted 215/232: SHEZAN POMEGRANATE NR BOTTLE JUICE 250 ML
# Extracted 216/232: SHEZAN TWIST MANGO JUICE 200ML
# Extracted 217/232: FRUITIEN JUICE ORANGE 100% PURE 1 LTR
# Extracted 218/232: FRUITIEN JUICE PEACH NECTAR 200 ML
# Extracted 219/232: SHEZAN TWIST MIXED FRUIT JUICE 200ML
# Extracted 220/232: FRESHER TETRA JUICE PEACH 200ML
# Extracted 221/232: FRESHER TETRA JUICE POMEGRANTE 200ML
# Extracted 222/232: SHEZAN JUICE FRUIT PUNCH 1 LTR- CARTON
# Extracted 223/232: SHEZAN JUICE FRUIT PUNCH 1 LTR
# Extracted 224/232: SHEZAN APPLE FRUIT DRINK 200 ML
# Extracted 225/232: FROOT FULL POMEGRANATE NECTAR CAN 250ML
# Extracted 226/232: SHEZAN GRAPE NR BOTTLE 250 ML- CARTON
# Extracted 227/232: SHEZAN GRAPE NR BOTTLE 250 ML
# Extracted 228/232: NESTLE NESFRUITA APPLE 1000ML
# Extracted 229/232: FROOT FULL GUAVA NECTAR CAN 250ML
# Extracted 230/232: MURREE BREWERY BLITZ BERRY JOLT CAN 250ML
# Extracted 231/232: SHEZAN JUICE MANGO 1 LTR- CARTON
# Extracted 232/232: SHEZAN JUICE MANGO 1 LTR
# Saved 232 products to: Groceries/local-drinks-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Groceries] → milk-price-in-pakistan
# URL: https://alfatah.pk/collections/milk-price-in-pakistan
# ================================================================================
# Found 37 products in milk-price-in-pakistan
# Extracted 1/37: OLPERS MILK FULL CREAM 250 ML
# Extracted 2/37: OLPERS MILK FULL CREAM 250 ML - POUCH CARTON
# Extracted 3/37: NESTLE MILKPAK MILK FULL CREAM 250ML
# Extracted 4/37: NESTLE MILKPAK MILK FULL CREAM 250ML - CARTON
# Extracted 5/37: OLPERS MILK 1 LTR
# Extracted 6/37: OLPERS MILK 1 LTR - CARTON
# Extracted 7/37: OLPERS MILK 1.5 LTR
# Extracted 8/37: OLPERS MILK 1.5 LTR - CARTON
# Extracted 9/37: Olpers Full Cream Milk 250 ML- CARTON
# Extracted 10/37: OLPERS FULL CREAM MILK TBA 250 ML
# Extracted 11/37: NESTLE MILKPAK MILK FULL CREAM 1 LTR
# Extracted 12/37: NESTLE MILKPAK MILK FULL CREAM 1 LTR- CARTON
# Extracted 13/37: NURPUR FULL CREAM MILK 125 ML
# Extracted 14/37: Nurpur Full Cream Milk 125 ml (Pack of 24)
# Extracted 15/37: NURPUR FULL CREAM MILK 1LTR
# Extracted 16/37: NURPUR FULL CREAM MILK 1 LTR - CARTON
# Extracted 17/37: TARANG TEA WHITENER 180ML
# Extracted 18/37: TARANG TEA WHITENER 175ML-CARTON
# Extracted 19/37: NESTLE NESVITA MILK MOVE PLUS STRONG BONES 1 LTR
# Extracted 20/37: NESTLE NESVITA MILK MOVE PLUS STRONG BONES 1 LTR - CARTON
# Extracted 21/37: NURPUR FULL CREAM MILK 250 ML
# Extracted 22/37: NURPUR FULL CREAM MILK - CARTON
# Extracted 23/37: OLPERS DAIRY OMUNG MILK 225 ML
# Extracted 24/37: OLPER'S LOW FAT MILK -CARTON
# Extracted 25/37: OLPERS MILK PROTEIN CALCIUM 1 LTR
# Extracted 26/37: TARANG LIQUID TEA WHITENER 225 ML
# Extracted 27/37: NURPUR FULL CREAM MILK 1.5 LTR WITH CAP
# Extracted 28/37: OLPER FULL CREAM MILK MINI PACK 125 ML
# Extracted 29/37: NESTLE MILK PAK LOW FAT YOGURT 900 GM
# Extracted 30/37: OLPERS DAIRY OMANG MILK 1 LTR
# Extracted 31/37: HALEEB UHT FULL CREAM MILK 1LTR
# Extracted 32/37: HALEEB UHT FULL CREAM MILK 1LTR - CARTON
# Extracted 33/37: OLPERS DAIRY OMUNG BUDGET PACK 1.5 LTR
# Extracted 34/37: DAYFRESH LIQUID MILK FULL CREAM 1 LTR
# Extracted 35/37: DAYFRESH LIQUID MILK FULL CREAM CAP 250 ML
# Extracted 36/37: DAY FRESH MILK LACTOSE FREE 1 LTR
# Extracted 37/37: MILK MAKEUP KUSH LIP OIL COOKIE DOUGH
# Saved 37 products to: Groceries/milk-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Groceries] → butter-price-in-pakistan
# URL: https://alfatah.pk/collections/butter-price-in-pakistan
# ================================================================================
# Found 44 products in butter-price-in-pakistan
# Extracted 1/44: LURPAK BUTTER MINI PC 10 GM
# Extracted 2/44: NURPUR BUTTER 200 GM
# Extracted 3/44: NURPUR BUTTER 100 GM
# Extracted 4/44: NURPUR BUTTER UNSALTED 200GM
# Extracted 5/44: ADAMS BUTTER 200 GM
# Extracted 6/44: NURPUR BUTTER 50 GM
# Extracted 7/44: PREMA PURE BUTTER 190GM
# Extracted 8/44: NESTLE MILKPAK BUTTER SALTED 100GM
# Extracted 9/44: NURPUR BUTTER 10GM
# Extracted 10/44: ADAMS UNSALTED WHITE BUTTER 200 GM
# Extracted 11/44: ADAMS BUTTER 100 GM
# Extracted 12/44: FF UN-SALTED BUTTER 250 GM
# Extracted 13/44: LURPAK BUTTER SLIGHTLY SALTED 200 GM
# Extracted 14/44: FF UN-SALTED BUTTER 100 GM
# Extracted 15/44: LURPAK BUTTER SPREADABLE SLIGHTLY SALTED 250 GM
# Extracted 16/44: ADAMS SALTED BUTTER 50GM
# Extracted 17/44: FF UN-SALTED BUTTER 500 GM
# Extracted 18/44: FF UN-SALTED BUTTER 1000 GM
# Extracted 19/44: LURPAK BUTTER UNSALTED 200 GM
# Extracted 20/44: LURPAK BUTTER SPREADABLE UNSALTED 250 GM
# Extracted 21/44: FF SALTED BUTTER 250 GM
# Extracted 22/44: NURPUR BUTTER SLIGHTLY SALTED 200GM
# Extracted 23/44: ADAMS BUTTER 1 KG
# Extracted 24/44: FF SALTED BUTTER 100 GM
# Extracted 25/44: FF SALTED BUTTER 8 GM
# Extracted 26/44: LURPAK BUTTER SIGHTLY SALTED 100 GM
# Extracted 27/44: LURPAK BUTTER SLIGHTLY SALTED 500 GM
# Extracted 28/44: LURPAK BUTTER LIGHTER SPREADABLE 250 GM
# Extracted 29/44: LURPAK BUTTER UNSALTED 400 GM
# Extracted 30/44: FF SALTED BUTTER 500 GM
# Extracted 31/44: NESTLE MILKPAK BUTTER SALTED 200GM
# Extracted 32/44: BUTTER STICK ON MEDIUM SIZE NAPKIN 16 PCS
# Extracted 33/44: FF SALTED BUTTER 1000 GM
# Extracted 34/44: NESTLE MILK PAK DAIRY BUTTER UNSALTED 200 GM
# Extracted 35/44: FRESH ST BUTTER SALTED 200GM
# Extracted 36/44: FRESH ST BUTTER SALTED 80 GM
# Extracted 37/44: FRESH ST BUTTER UNSALTED 200 GM
# Extracted 38/44: FRESH ST BUTTER SALTED 100GM
# Extracted 39/44: FRESH ST BUTTER UNSALTED 100 GM
# Extracted 40/44: FRESH ST BUTTER GARLIC & HERB 100GM
# Extracted 41/44: FRESH ST BUTTER UNSALTED 80 Gm
# Extracted 42/44: FF SALTED BUTTER 8 GM (10 PCS)
# Extracted 43/44: FF SALTED BUTTER 8 GM (20 PCS)
# Extracted 44/44: PAM SPRAY NON STICK BUTTER BEURRE DANGER 141 GM
# Saved 44 products to: Groceries/butter-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Groceries] → egg-price-in-pakistan
# URL: https://alfatah.pk/collections/egg-price-in-pakistan
# ================================================================================
# Found 10 products in egg-price-in-pakistan
# Extracted 1/10: FF HAPPY HEN CLASSIC EGGS 12 PCS
# Extracted 2/10: FF HAPPY HEN CLASSIC EGGS 6 PCS
# Extracted 3/10: FF HAPPY HEN CLASSIC EGGS 30 PCS
# Extracted 4/10: ORGANIC VALLEY LOHMAN BROWN EGG ECONOMY 12 PC
# Extracted 5/10: FF HAPPY HEN DESI EGGS 12 PCS
# Extracted 6/10: FF HAPPY HEN DHA OMEGA 3 EGGS (L) 12 PCS
# Extracted 7/10: ORGANIC VALLEY LOHMAN BROWN EGG FAMILY 30 PC
# Extracted 8/10: ORGANIC VALLEY LOHMAN BROWN EGG SAVER 6 PC
# Extracted 9/10: FF HAPPY HEN JUMBO CLASSIC EGGS 12 PCS
# Extracted 10/10: ORGANIC VALLEY LOHMAN BROWN EGG LARGE 6 PC
# Saved 10 products to: Groceries/egg-price-in-pakistan.csv
#
# ####################################################################################################
# Processing MAIN CATEGORY: Electronics
# ####################################################################################################
#
# ================================================================================
# Scraping [Electronics] → air-purifier-price-in-pakistan
# URL: https://alfatah.pk/collections/air-purifier-price-in-pakistan
# ================================================================================
# Found 31 products in air-purifier-price-in-pakistan
# Extracted 1/31: ROYAL AIR PURIFIER RAP-5000
# Extracted 2/31: BEURER CARTRIDGE LR210/200
# Extracted 3/31: BEURER AIR PURIFIER LR210
# Extracted 4/31: BEURER AIR PURIFIER LR401
# Extracted 5/31: PHILIPS AIR PURIFIER AC4220/12
# Extracted 6/31: PHILIPS AIR PURIFIER AMF870
# Extracted 7/31: BEURER AIR PURIFIER LR500
# Extracted 8/31: PHILIPS AIR PURIFIER 0921
# Extracted 9/31: BEURER AIR PURIFIER CARTRIDGE LR500
# Extracted 10/31: PHILIP AIR PURFIER AC0819
# Extracted 11/31: G.F.C AIR PURIFIER MODEL GF-400
# Extracted 12/31: PHILIPS AIR PURIFIER 1000I AC1715/71 BLACK
# Extracted 13/31: BEURER AIR PURIFIER LR310
# Extracted 14/31: G.F.C AIR PURIFIER MODEL GF-270
# Extracted 15/31: PHILIPS AIR PURIFIER AC0850
# Extracted 16/31: BRAUN AIR PURIFER BFD104
# Extracted 17/31: BEURER AIR PURIFIER FILTER LR400/405
# Extracted 18/31: PHILIP FILTER 1700/30
# Extracted 19/31: PHILIPS AIR PURIFIER AMF765/30
# Extracted 20/31: PHILIPS AIR PURIFIER AC3737/10
# Extracted 21/31: PHILIPS AIR PURIFIER AC1711/90
# Extracted 22/31: BEURER CARTRIDGE LR220
# Extracted 23/31: LEVOIT AIR PURIFIER LAP-C601S-WAF
# Extracted 24/31: PHILIPS AIR PURIFIRE AC2939
# Extracted 25/31: PANASONIC HUMIDIFYING AIR PURIFIER F-VCM85M
# Extracted 26/31: MEILLEUR DISINFECTION LAMP WHITE UVHG2036415
# Extracted 27/31: TEFAL AIR PURIFIER PREFILTER PU0008
# Extracted 28/31: PHILIP FILTER AC2887 + FY2422 FY2420AB
# Extracted 29/31: LEVOIT AIR PURIFIER CORE 300-RF
# Extracted 30/31: LEVOIT AIR PURIFIER CORE 300S/0153
# Extracted 31/31: BRAUN AIR PURIFIER FILTER BRFV1E
# Saved 31 products to: Electronics/air-purifier-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Electronics] → microwave-oven-price-in-pakistan
# URL: https://alfatah.pk/collections/microwave-oven-price-in-pakistan
# ================================================================================
# Found 90 products in microwave-oven-price-in-pakistan
# Extracted 1/90: MEILLEUR ELECTRIC OVEN IR MEO-40
# Extracted 2/90: KENWOOD MICROWAVE OVEN MWK62.000SS
# Extracted 3/90: WEST POINT ELECTRIC OVEN 45LTR 4500
# Extracted 4/90: MEILLEUR ELECTRIC OVEN IR MEO-38
# Extracted 5/90: DAWLANCE MICROWAVE OVEN MD10
# Extracted 6/90: PEL MICROWAVE OVEN 23LTR PMO23 DESIRE BL BLACK
# Extracted 7/90: PANASONIC MICROWAVE OVEN 28LTR CONVECTION CD67MBKPQ
# Extracted 8/90: KENWOOD MICROWAVE OVEN MWP31.010SI
# Extracted 9/90: KENWOOD MICROWAVE OVEN MWP31.020SI
# Extracted 10/90: PEL MICROWAVE OVEN PMO26 CHEFF
# Extracted 11/90: DAWLANCE MICROWAVE OVEN 30LTR DW131
# Extracted 12/90: MEILLEUR ELECTRIC OVEN IR MEO-100
# Extracted 13/90: DAWLANCE MICROWAVE OVEN MD4
# Extracted 14/90: MEILLEUR ELECTRIC OVEN IR MEO-55
# Extracted 15/90: MEILLEUR ELECTRIC OVEN IR MEO-70
# Extracted 16/90: WEST POINT ELECTRIC OVEN 48LTR 4800RKC
# Extracted 17/90: DAWLANCE MICROWAVE INVERTER MD20
# Extracted 18/90: DAWLANCE MICROWAVE OVE 26LTR 128G PC
# Extracted 19/90: DAWLANCE MICROWAVE OVEN 23LTR DW374
# Extracted 20/90: DAWLANCE MICROWAVE OVEN 36LTR DW136G
# Extracted 21/90: DAWLANCE MICROWAVE 30LTR DW-132-S PC
# Extracted 22/90: BLACK & DECKER OVEN TOASTER 55LTR TRO55RDG
# Extracted 23/90: DAWLANCE MICROWAVE OVEN DW210 BASIC
# Extracted 10/25: Ps4 D/S Orignal Slim Pc
# Extracted 11/25: Ps4 Orignal D/S Redcol Pc
# Extracted 12/25: Ps4 Orignal D/S Kamo Pc
# Extracted 13/25: PS 5 CONSOLE SLIM 1TB (UK)
# Extracted 14/25: PS4 CONSOLO PROTECTOR SLICON CASE PC
# Extracted 15/25: PS4 RACING WHEEL VIBRATION.
# Extracted 16/25: PS5 CONSOLE PRO 2TB
# Extracted 17/25: PS4 DOBE SILICONE
# Extracted 18/25: XBOX SERIES D/SHOCK DEEP PINK ORG
# Extracted 19/25: PS5 D/S SPIDERMAN 2 EDITION
# Extracted 20/25: X BOX ONE DUAL SHOCK CHARGING STAND
# Extracted 21/25: KBOX SERIES D/SHOCK ELECTRIC VOLT ORIGINA
# Extracted 22/25: PXN RACINGWHEEL V10
# Extracted 23/25: NINTENDO SWITCH 2
# Extracted 24/25: X BOX MICROSOFT ONE X
# Extracted 25/25: PS4 CONTROLLER THUMB FREEK PC
# Saved 25 products to: Toys/gaming-console-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Toys] → video-game-price-in-pakistan
# URL: https://alfatah.pk/collections/video-game-price-in-pakistan
# ================================================================================
# Found 185 products in video-game-price-in-pakistan
# Extracted 1/185: Ps5 Game Gta V
# Extracted 2/185: Ps4 Game Gta V
# Extracted 3/185: Ps4 Game Disc Tekken 7 Pc
# Extracted 4/185: Ps4 Game Disc Mine Craft Pc
# Extracted 5/185: Sw Game Mario Kart Delux
# Extracted 6/185: Ps4 Dvd Nfs Heat
# Extracted 7/185: Ps5 Game Gran Turismo 7
# Extracted 8/185: Ps5 Game Nfs Unbound
# Extracted 9/185: Ps4 Racing Well V9
# Extracted 10/185: Ps4 Game Gran Turismo 7
# Extracted 11/185: Ps4 Game Marcel Spiderman Miles Morales
# Extracted 12/185: Ps4 Game Cod Vanguard
# Extracted 13/185: Ps4 Gane Disc Marvel Spider Men Pc
# Extracted 14/185: Ns Game Minecraft Dungeons Hero Edition
# Extracted 15/185: Ps5 Game Cod Mw2
# Extracted 16/185: Ps 4 Dvd Lego Batman
# Extracted 17/185: Ps5 Game Elden Ring
# Extracted 18/185: Sw Game Minecraft
# Extracted 19/185: Ps5 Game God Of War Ragnarok
# Extracted 20/185: Ps5 Game Hogwarts Legacy
# Extracted 21/185: Ns Game Hello Neighbour Hide&Seek
# Extracted 22/185: Ps5 Game Sonic Frontiers
# Extracted 23/185: Ps4 Game Terminator
# Extracted 24/185: Ps4 Game Cod B/Ops4 R-All Pc
# Extracted 25/185: Ps4 Game W2K23
# Extracted 26/185: Ps5 Game Fifa 2023
# Extracted 27/185: Ps4 Game Disc God Of War Pc
# Extracted 28/185: Ps4 Game Disc Crew 2
# Extracted 29/185: X Box One Game D/S Nba2K18 Pc
# Extracted 30/185: Ps 4 Dvd Assassins Creed Valhalla
# Extracted 31/185: Ps5 Game Nickelodeon All Stars
# Extracted 32/185: Ns Sniper Elite Ultimate
# Extracted 33/185: Ps 5 Dvd Cod Black Ops Cold War
# Extracted 144/185: NS GAME OCTOPATH TRAVELER II
# Extracted 145/185: X BOX ONE GAME DISC DESTINY PC
# Extracted 146/185: PS5 GAME COD VANGUARD
# Extracted 147/185: PS4 CRSH TEAM RUMBLE
# Extracted 148/185: PS4 GAME COD MW3
# Extracted 149/185: PS5 GAME COD MW3
# Extracted 150/185: SONY PSP TIGER WOODS PGA 2010 PC
# Extracted 151/185: PS4 GAME DISC MIRRORS EDGE
# Extracted 152/185: X BOX BATTLE FILED 1
# Extracted 153/185: PS5 GAME MADDEN 22 EA SPORTS
# Extracted 154/185: X BOX ONE GAME FIFA 20
# Extracted 155/185: PS4 FC 24
# Extracted 156/185: XBOX SERIES GEME NFS UNBOUND
# Extracted 157/185: SONY PS4 NEED FOR SPEED RIVALS PC
# Extracted 158/185: PS4 DVD BURNOUT PARADISE REMASTER PC
# Extracted 159/185: X BOX ONE GMA EDISC LEGO BATMAN 3 PC
# Extracted 160/185: PS4 GAME DISC LEGO JURASIC WORLD PC
# Extracted 161/185: PS4 SONIC ORIGINS PLUS
# Extracted 162/185: PS4 LIKE A GRAGON INFINITE WEALTH
# Extracted 163/185: PS4 GAME HOGWARTS LEGACY
# Extracted 164/185: PS5 GAME HELLO NEIGHBOR 2
# Extracted 165/185: PS5 GAME LORDS OF THE FALLEN
# Extracted 166/185: SONY PS4 USB CABLE PC
# Extracted 167/185: X BOX ONE VERICAL SLIM STAND PC
# Extracted 168/185: PS5 GAME HOT WHEELS UNLEASHED
# Extracted 169/185: SONY PSP HANNAH MONTANA PC
# Extracted 170/185: PS5 FIGHT FOREVER
# Extracted 171/185: PS4 GAME CRASH BANDICOOT 4
# Extracted 172/185: PS4 GAME RED DEAD REDEMPTION 2
# Extracted 173/185: PSN 50 S CARD PC
# Extracted 174/185: PS4 PSN 25$ CARD
# Extracted 175/185: XBOX ONE GAME DISC DIVISION 2
# Extracted 176/185: PS4 AC MIRAGE
# Extracted 177/185: X BOX ONE GAME DISC DARK SOUL PC
# Extracted 178/185: X BOX ONE DVD DBZ KAKAROT
# Extracted 179/185: PS5 GAME BANISHERS
# Extracted 180/185: PS 4 DVD ZONE OF ENDERS PC
# Extracted 181/185: PS5 GAME FC 24
# Extracted 182/185: PS4 GAME SONIC COLOURS ULTIMATE
# Extracted 183/185: X BOX ONE GAME RAGE 2
# Extracted 184/185: NINTEN SWITCH BAGS PC
# Extracted 185/185: HDMI CABLE 5M
# Saved 185 products to: Toys/video-game-price-in-pakistan.csv
#
# ================================================================================
# Scraping [Toys] → activity-toys
# URL: https://alfatah.pk/collections/activity-toys
# ================================================================================
# Found 39 products in activity-toys
# Extracted 1/39: TY9055 TANNY KIDS CUP O FUN SHAPES ID
# Extracted 2/39: TY9080 TANNY KIDS BATH TOY 3PC ID
# Extracted 3/39: 2258 WIN FUN LEARNING DRAW BOARD BASIC
# Extracted 4/39: 1142 WIN FUN RAINBOW PUP BASIC
# Extracted 5/39: TY9056 TANNY KIDS HAPPY PHONE B/O ID
# Extracted 6/39: TY9063 TANNY KIDS ROCKING FUNNY RINGS STACKING ID
# Extracted 7/39: TY9025 TANNY KIDS PLAYTIME POUNDING STACKER ID
# Extracted 8/39: 919-002A BABY PLAY GYM IR
# Extracted 9/39: TY9048 TANNY KIDS SHAPE SORTING CUBE ID
# Extracted 10/39: TY9059 TANNY KIDS MAGIC TWIST TEATHER ID
# Extracted 11/39: TY9083 TANNY KIDS ROTATE AND FUN TOY ID
# Extracted 12/39: TY9069 TANNY KIDS PUSH N RUN CATERPILLAR ID
# Extracted 13/39: CHI-5225 CHICHOOO GOAL LEAGUE
# Extracted 14/39: 2400 WINFUN VOICE CHANGING DINO BASIC
# Extracted 15/39: TY9054 TANNY KIDS JUMPING LADYBUG ID
# Extracted 16/39: TY9067 TANNY KIDS STACING CUPS ID
# Extracted 17/39: TY9037 TANNY KIDS FANNY ELEPHANT JUMBO SHAPE SORTER ID
# Extracted 18/39: TY9068 TANNY KIDS WATER FUN KETTLE ID
# Extracted 19/39: TY9072 TANNY KIDS STACKING ACTIVITY BLOCKS ID
# Extracted 20/39: 12268 NXS RACERS SPEED TUNNEL
# Extracted 21/39: TY9040 TANNY KIDS BABY RATTLE ID
# Extracted 22/39: 0674 WIN FUN SPIN N OWL SNAIL
# Extracted 23/39: TY9078 TANNY KIDS OCEAN CUPS SHPAES ID
# Extracted 24/39: TY9076 TANNY KIDS FLOWER RATTLE ID
# Extracted 25/39: TY9061 TANNY KIDS FUNNY STACKING SHAPES ID
# Extracted 26/39: 80017 LEPIN DRAGON DANCE
# Extracted 27/39: TY9075 TANNY KIDS PUZZLE (SHAPES) STACKING ID
# Extracted 28/39: TY9034 TANNY KIDS RAINBOW CAROUSEL SPINNER ID
# Extracted 29/39: TY9047 TANNY KIDS FUNNY BALL SHAPE SORTER ID
# Extracted 30/39: TY9073 TANNY KIDS GEOMETRIC FLOWER PUZZLE ID
# Extracted 31/39: 2204 BABY CORT MOBILE HELICOPTER
# Extracted 32/39: TY9079 TANNY KIDS MUSIC BOX ID
# Extracted 33/39: TY9052 TANNY KIDS BATH FUN PLAY SET ID
# Extracted 34/39: TY9050 TANNY KIDS PUZZLE PLAY SET ID
# Extracted 35/39: TY9044 TANNY KIDS FANNY HIPPO SHAPE SORTER ID
# Extracted 36/39: TY9082 TANNY KIDS OCEAN SET ID
# Extracted 37/39: 1141 WIN FUN WALK WITH ME DINOBOO
# Extracted 38/39: FRESH METAL DINOTROPOLIS MEGA PLAYSET 12398
# Extracted 39/39: 7600310506 TEFAL COFFEE EXPRESS..
# Saved 39 products to: Toys/activity-toys.csv
#
# ================================================================================
# Scraping [Toys] → baby-push-car-price-in-pakistan
# URL: https://alfatah.pk/collections/baby-push-car-price-in-pakistan
# ================================================================================
# Found 52 products in baby-push-car-price-in-pakistan
# Extracted 1/52: PUSHING CAR TOYS STORY 058768 D
# Extracted 2/52: Pushing Car Bc3311M
# Extracted 3/52: PUSHING CAR CARS 3 049437 D
# Extracted 4/52: Pushing Car Bc-5402
# Extracted 5/52: DINASOUR PUSHING CAR QX-5501C H.D
# Extracted 6/52: Pushing Car Avengers 3311M H.B
# Extracted 7/52: PUSHING CAR PAW PETROL 055475 D
# Extracted 8/52: 051433 PUSHING CAR BASIC
# Extracted 9/52: PUSHING CAR FROZEN 2 060855 D
# Extracted 10/52: ZURU TINY TOWN PUSHING CAR 10602 D
# Extracted 11/52: BABY TWISTER CAR T-008 BBZ
# Extracted 12/52: TWISTER CAR S5275 D
# Extracted 13/52: BABY PUSHING CAR WITH HANDLE 3622
# Extracted 14/52: RIDE ON CAR PUSHING CAR J-BC300
# Extracted 15/52: BABY PUSHING CAR IR 1688-1
# Extracted 16/52: 12-4 KIDS PUSSING PLANE
# Extracted 17/52: 12-4 KIDS PUSSING HEN
# Extracted 18/52: BABY PUSHING CAR 7628
# Extracted 19/52: PUSHING CAR ROAD MASTER IR QX-3372-3
# Extracted 20/52: PUSHING CAR ASST TM-5
# Extracted 21/52: BABY PUSHING CAR IR LT-188
# Extracted 22/52: BABY PUSHING CAR DOG IR XFC-116
# Extracted 23/52: BABY PUSHING CAR IR XFC-118
# Extracted 24/52: MUSICAL TWISTER TRAIN ENGINE 809
# Extracted 25/52: BABY PUSHING CAR MICKEY MOUSE 3385-1
# Extracted 26/52: PUSHING CAR 6551
# Extracted 27/52: TWISTER CAR 8800A
# Extracted 28/52: SUPER WINGS BABY PUSHING CAR FD-6816 H.B
# Extracted 29/52: BABY PUSHING CAR HELLO KITTY 3383-1
# Extracted 30/52: PUSHING CAR BC8206M BASIC
# Extracted 31/52: BABY PUSHING CAR LOL 3311L
# Extracted 32/52: BABY PUSHING ALONG BIKE 4WHEEL IR 517
# Extracted 33/52: RECHARGEABLE MOTOR CYCLE 3WHEEL IR HK-969-3
# Extracted 34/52: PUSHING BIKE 4WHEEL IR TX-2430
# Extracted 35/52: KIDS 4WHEEL SCOOTER IR ZT-3912
# Extracted 36/52: QX3374 PHANTOM PUSHING CAR
# Extracted 37/52: TWISTER CAR T669
# Extracted 38/52: BABY PUSHING CAR KB-019-4P
# Extracted 39/52: BABY TWISTER CAR QT8081
# Extracted 40/52: BABY TWISTER CAR HL819
# Extracted 41/52: BABY PUSHING CAR T118
# Extracted 42/52: BABY PUSHING CAR IR HB-166
# Extracted 43/52: BABY PUSHING ALONG BIKE 4WHEEL IR QL-688
# Extracted 44/52: PUSHING BIKE 4WHEEL IR TX-2431
# Extracted 45/52: BABY PUSHING CAR 319 KB049
# Extracted 46/52: BABY PUSHING CAR PANDA IR YH-S1
# Extracted 47/52: BABY PUSHING ALONG BIKE 4WHEEL IR 271
# Extracted 48/52: BABY PUSHING ALONG BIKE 4WHEEL IR 518
# Extracted 49/52: BABY PUSHING ALONG BIKE 4WHEEL IR 516
# Extracted 50/52: BABY PUSHING ALONG BIKE 4WHEEL IR QL-925
# Extracted 51/52: BABY PUSHING CAR DORAEMON 3312
# Extracted 52/52: 35207B PULLBACK COW RATTLE CAR IR
# Saved 52 products to: Toys/baby-push-car-price-in-pakistan.csv
#
# All categories processed successfully.
